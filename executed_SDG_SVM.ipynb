# %% [markdown]
# ## Libraries

# %%
Sys.setenv("PKG_CXXFLAGS"="-std=c++14")

# List of required packages
list_of_packages <- c(
  "synthpop", "jsonlite", "codetools", "insight", "party", "haven", "dplyr", "rpart", "rpart.plot",
  "randomForest", "pROC", "caret", "pracma", "here", "Hmisc", "purrr",
  "ranger", "bnlearn", "arulesCBA", "network", "igraph", "xgboost",
  "data.table", "RSNNS", "xgboost", "data.table", "Matrix", "e1071"
)

# Function to load packages and handle errors
load_if_installed <- function(p) {
  tryCatch({
    library(p, character.only = TRUE)
  }, error = function(e) {
    message(sprintf("Package '%s' is not installed.", p))
  })
}

# Load all required packages
lapply(list_of_packages, load_if_installed)
# Out:
# Find out more at https://www.synthpop.org.uk/
# Loading required package: grid
# Loading required package: mvtnorm
# Loading required package: modeltools
# Loading required package: stats4
# Loading required package: strucchange
# Loading required package: zoo
# Attaching package: ‘zoo’
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
# Loading required package: sandwich
# Attaching package: ‘dplyr’
# The following object is masked from ‘package:party’:
#
#     where
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# randomForest 4.7-1.1
# Type rfNews() to see new features/changes/bug fixes.
# Attaching package: ‘randomForest’
# The following object is masked from ‘package:dplyr’:
#
#     combine
# Type 'citation("pROC")' for a citation.
# Attaching package: ‘pROC’
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
# Loading required package: ggplot2
# Attaching package: ‘ggplot2’
# The following object is masked from ‘package:randomForest’:
#
#     margin
# Loading required package: lattice
# here() starts at /home/uni08/hpc/emma.foessing01/u11969/Master-Thesis
# Attaching package: ‘Hmisc’
# The following object is masked from ‘package:pracma’:
#
#     ceil
# The following objects are masked from ‘package:dplyr’:
#
#     src, summarize
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
# Attaching package: ‘purrr’
# The following object is masked from ‘package:pracma’:
#
#     cross
# The following object is masked from ‘package:caret’:
#
#     lift
# The following object is masked from ‘package:jsonlite’:
#
#     flatten
# Attaching package: ‘ranger’
# The following object is masked from ‘package:randomForest’:
#
#     importance
# Package 'bnlearn' is not installed.
# Package 'arulesCBA' is not installed.
# Package 'network' is not installed.
# Package 'igraph' is not installed.
# Attaching package: ‘data.table’
# The following object is masked from ‘package:purrr’:
#
#     transpose
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
# The following objects are masked from ‘package:zoo’:
#
#     yearmon, yearqtr
# Loading required package: Rcpp
# Attaching package: ‘RSNNS’
# The following objects are masked from ‘package:caret’:
#
#     confusionMatrix, train
# Attaching package: ‘Matrix’
# The following objects are masked from ‘package:pracma’:
#
#     expm, lu, tril, triu
# Attaching package: ‘e1071’
# The following object is masked from ‘package:Hmisc’:
#
#     impute
# The following object is masked from ‘package:pracma’:
#
#     sigmoid
# [[1]]
# [1] "synthpop"  "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
# [1] "jsonlite"  "synthpop"  "stats"     "graphics"  "grDevices" "utils"
# [7] "datasets"  "methods"   "base"
#
# [[3]]
#  [1] "codetools" "jsonlite"  "synthpop"  "stats"     "graphics"  "grDevices"
#  [7] "utils"     "datasets"  "methods"   "base"
#
# [[4]]
#  [1] "insight"   "codetools" "jsonlite"  "synthpop"  "stats"     "graphics"
#  [7] "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[5]]
#  [1] "party"       "strucchange" "sandwich"    "zoo"         "modeltools"
#  [6] "stats4"      "mvtnorm"     "grid"        "insight"     "codetools"
# [11] "jsonlite"    "synthpop"    "stats"       "graphics"    "grDevices"
# [16] "utils"       "datasets"    "methods"     "base"
#
# [[6]]
#  [1] "haven"       "party"       "strucchange" "sandwich"    "zoo"
#  [6] "modeltools"  "stats4"      "mvtnorm"     "grid"        "insight"
# [11] "codetools"   "jsonlite"    "synthpop"    "stats"       "graphics"
# [16] "grDevices"   "utils"       "datasets"    "methods"     "base"
#
# [[7]]
#  [1] "dplyr"       "haven"       "party"       "strucchange" "sandwich"
#  [6] "zoo"         "modeltools"  "stats4"      "mvtnorm"     "grid"
# [11] "insight"     "codetools"   "jsonlite"    "synthpop"    "stats"
# [16] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [21] "base"
#
# [[8]]
#  [1] "rpart"       "dplyr"       "haven"       "party"       "strucchange"
#  [6] "sandwich"    "zoo"         "modeltools"  "stats4"      "mvtnorm"
# [11] "grid"        "insight"     "codetools"   "jsonlite"    "synthpop"
# [16] "stats"       "graphics"    "grDevices"   "utils"       "datasets"
# [21] "methods"     "base"
#
# [[9]]
#  [1] "rpart.plot"  "rpart"       "dplyr"       "haven"       "party"
#  [6] "strucchange" "sandwich"    "zoo"         "modeltools"  "stats4"
# [11] "mvtnorm"     "grid"        "insight"     "codetools"   "jsonlite"
# [16] "synthpop"    "stats"       "graphics"    "grDevices"   "utils"
# [21] "datasets"    "methods"     "base"
#
# [[10]]
#  [1] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "haven"
#  [6] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [11] "stats4"       "mvtnorm"      "grid"         "insight"      "codetools"
# [16] "jsonlite"     "synthpop"     "stats"        "graphics"     "grDevices"
# [21] "utils"        "datasets"     "methods"      "base"
#
# [[11]]
#  [1] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
#  [6] "haven"        "party"        "strucchange"  "sandwich"     "zoo"
# [11] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [16] "codetools"    "jsonlite"     "synthpop"     "stats"        "graphics"
# [21] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[12]]
#  [1] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
#  [6] "rpart.plot"   "rpart"        "dplyr"        "haven"        "party"
# [11] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [16] "mvtnorm"      "grid"         "insight"      "codetools"    "jsonlite"
# [21] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [26] "datasets"     "methods"      "base"
#
# [[13]]
#  [1] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
#  [6] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "haven"
# [11] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [16] "stats4"       "mvtnorm"      "grid"         "insight"      "codetools"
# [21] "jsonlite"     "synthpop"     "stats"        "graphics"     "grDevices"
# [26] "utils"        "datasets"     "methods"      "base"
#
# [[14]]
#  [1] "here"         "pracma"       "caret"        "lattice"      "ggplot2"
#  [6] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
# [11] "haven"        "party"        "strucchange"  "sandwich"     "zoo"
# [16] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [21] "codetools"    "jsonlite"     "synthpop"     "stats"        "graphics"
# [26] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[15]]
#  [1] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
#  [6] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [11] "dplyr"        "haven"        "party"        "strucchange"  "sandwich"
# [16] "zoo"          "modeltools"   "stats4"       "mvtnorm"      "grid"
# [21] "insight"      "codetools"    "jsonlite"     "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[16]]
#  [1] "purrr"        "Hmisc"        "here"         "pracma"       "caret"
#  [6] "lattice"      "ggplot2"      "pROC"         "randomForest" "rpart.plot"
# [11] "rpart"        "dplyr"        "haven"        "party"        "strucchange"
# [16] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [21] "grid"         "insight"      "codetools"    "jsonlite"     "synthpop"
# [26] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [31] "methods"      "base"
#
# [[17]]
#  [1] "ranger"       "purrr"        "Hmisc"        "here"         "pracma"
#  [6] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
# [11] "rpart.plot"   "rpart"        "dplyr"        "haven"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "codetools"    "jsonlite"
# [26] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [31] "datasets"     "methods"      "base"
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
#  [1] "xgboost"      "ranger"       "purrr"        "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "haven"
# [16] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [21] "stats4"       "mvtnorm"      "grid"         "insight"      "codetools"
# [26] "jsonlite"     "synthpop"     "stats"        "graphics"     "grDevices"
# [31] "utils"        "datasets"     "methods"      "base"
#
# [[23]]
#  [1] "data.table"   "xgboost"      "ranger"       "purrr"        "Hmisc"
#  [6] "here"         "pracma"       "caret"        "lattice"      "ggplot2"
# [11] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
# [16] "haven"        "party"        "strucchange"  "sandwich"     "zoo"
# [21] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [26] "codetools"    "jsonlite"     "synthpop"     "stats"        "graphics"
# [31] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[24]]
#  [1] "RSNNS"        "Rcpp"         "data.table"   "xgboost"      "ranger"
#  [6] "purrr"        "Hmisc"        "here"         "pracma"       "caret"
# [11] "lattice"      "ggplot2"      "pROC"         "randomForest" "rpart.plot"
# [16] "rpart"        "dplyr"        "haven"        "party"        "strucchange"
# [21] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [26] "grid"         "insight"      "codetools"    "jsonlite"     "synthpop"
# [31] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [36] "methods"      "base"
#
# [[25]]
#  [1] "RSNNS"        "Rcpp"         "data.table"   "xgboost"      "ranger"
#  [6] "purrr"        "Hmisc"        "here"         "pracma"       "caret"
# [11] "lattice"      "ggplot2"      "pROC"         "randomForest" "rpart.plot"
# [16] "rpart"        "dplyr"        "haven"        "party"        "strucchange"
# [21] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [26] "grid"         "insight"      "codetools"    "jsonlite"     "synthpop"
# [31] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [36] "methods"      "base"
#
# [[26]]
#  [1] "RSNNS"        "Rcpp"         "data.table"   "xgboost"      "ranger"
#  [6] "purrr"        "Hmisc"        "here"         "pracma"       "caret"
# [11] "lattice"      "ggplot2"      "pROC"         "randomForest" "rpart.plot"
# [16] "rpart"        "dplyr"        "haven"        "party"        "strucchange"
# [21] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [26] "grid"         "insight"      "codetools"    "jsonlite"     "synthpop"
# [31] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [36] "methods"      "base"
#
# [[27]]
#  [1] "Matrix"       "RSNNS"        "Rcpp"         "data.table"   "xgboost"
#  [6] "ranger"       "purrr"        "Hmisc"        "here"         "pracma"
# [11] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
# [16] "rpart.plot"   "rpart"        "dplyr"        "haven"        "party"
# [21] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [26] "mvtnorm"      "grid"         "insight"      "codetools"    "jsonlite"
# [31] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [36] "datasets"     "methods"      "base"
#
# [[28]]
#  [1] "e1071"        "Matrix"       "RSNNS"        "Rcpp"         "data.table"
#  [6] "xgboost"      "ranger"       "purrr"        "Hmisc"        "here"
# [11] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [16] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "haven"
# [21] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [26] "stats4"       "mvtnorm"      "grid"         "insight"      "codetools"
# [31] "jsonlite"     "synthpop"     "stats"        "graphics"     "grDevices"
# [36] "utils"        "datasets"     "methods"      "base"

# %% [markdown]
# ## Data

# %%
# set path
############## adjust to correct directory!
directory <- "/user/emma.foessing01/u11969/Master-Thesis"

load(file = (paste0(directory, "/cpspop.RData")))
adult <- read.csv(file = paste0(directory,"/adult_preprocessed.csv"))
# delete NAs
adult[adult == "?"] <- NA
adult <- na.omit(adult)

adult$workclass <- as.factor(adult$workclass)
adult$education <- as.factor(adult$education)
adult$marital_status <- as.factor(adult$marital_status)
adult$relationship <- as.factor(adult$relationship)
adult$race <- as.factor(adult$race)
adult$sex <- as.factor(adult$sex)
adult$native_country <- as.factor(adult$native_country)
adult$income <- as.factor(adult$income)
adult$occupation <- as.factor(adult$occupation)

# %% [markdown]
# ## SDG

# %% [markdown]
# Key Features of the Implementation:
# 1. Sequential Synthesis:
#
# The synthesis process starts with sampling the sex variable (or another specified first variable) and then synthesizes each subsequent variable based on the previously synthesized variables.
#
# 2. SVM Model:
#
# The SVM model (svm()) is trained for each variable, using the synthesized variables up to that point as predictors.
# For factor variables, SVM classification (C-classification) is used.
# For numeric variables, SVM regression (eps-regression) is used.
#
# 3. Restoring the Original Structure:
#
# After synthesis, the function restores the original structure of the dataframe, including factor levels and numeric types.
#
# ### Parameters:
# kernel: The kernel type for the SVM model ("radial", "linear", etc.). <br>
# cost: The regularization parameter, which controls the trade-off between achieving a low error on the training data and minimizing the model complexity. <br>
# epsilon: The tolerance for regression (only relevant for regression tasks).

# %%
# Function to convert dataframe to a numeric matrix with one-hot encoding for factors
convert_to_numeric_matrix <- function(df) {
  df_numeric <- model.matrix(~ . - 1, data = df)  # One-hot encode factors, remove intercept
  return(as.matrix(df_numeric))
}

# Function to restore factors and numeric values to match the original dataframe
restore_factors_and_numeric <- function(original_df, synthesized_df) {
  synthesized_df[] <- lapply(seq_along(original_df), function(i) {
    original_col <- original_df[[i]]
    
    if (is.factor(original_col)) {
      # Restore factors with original levels
      levels <- levels(original_col)
      return(factor(synthesized_df[[i]], levels = seq_along(levels), labels = levels))
    } else if (is.numeric(original_col)) {
      # Ensure numeric columns are numeric
      return(as.numeric(synthesized_df[[i]]))
    } else {
      # Preserve any other types (shouldn't occur in this case)
      return(synthesized_df[[i]])
    }
  })
  
  colnames(synthesized_df) <- colnames(original_df)  # Restore original column names
  return(as.data.frame(synthesized_df))  # Ensure it is returned as a dataframe
}

# Function to build and train an SVM using e1071
build_svm <- function(X, y, type = "C-classification", kernel = "radial", cost = 1, epsilon = 0.1) {
  model <- svm(
    x = X,
    y = y,
    type = type,               # SVM type: classification or regression
    kernel = kernel,           # Kernel type: radial, linear, etc.
    cost = cost,               # Regularization parameter
    epsilon = epsilon          # Tolerance for regression (only used if type is regression)
  )
  
  return(model)
}

# Function to synthesize data sequentially starting from a specified first variable (e.g., 'sex')
synthesize_data_svm <- function(data, first_var, kernel = "radial", cost = 1, epsilon = 0.1) {
  # Ensure the first variable exists in the data
  if (!first_var %in% colnames(data)) {
    stop(paste("The column", first_var, "does not exist in the dataframe."))
  }
  
  # Initialize synthetic data with the same structure as the original data
  data_synth <- data.frame(matrix(NA, ncol = ncol(data), nrow = nrow(data)))
  colnames(data_synth) <- colnames(data)
  
  # Step 1: Directly sample the first variable (e.g., 'sex') from the original data
  data_synth[[first_var]] <- sample(data[[first_var]], nrow(data), replace = TRUE)
  
  # Step 2: Synthesize the remaining variables sequentially based on the already synthesized data
  remaining_vars <- setdiff(colnames(data), first_var)
  
  for (var in remaining_vars) {
    print(paste("Synthesizing variable:", var))
    
    # Identify predictors (all synthesized columns up to this point)
    predictors <- colnames(data_synth)[!is.na(data_synth[1, ]) & colnames(data_synth) != var]
    
    # Prepare data for SVM by converting all predictors to numeric with one-hot encoding
    X <- convert_to_numeric_matrix(data_synth[, predictors, drop = FALSE])
    y <- data[[var]]
    
    # Determine SVM type (classification or regression)
    if (is.factor(y)) {
      svm_type <- "C-classification"
      y_numeric <- as.numeric(y)
    } else {
      svm_type <- "eps-regression"
      y_numeric <- y
    }
    
    # Train the SVM model using e1071
    model <- build_svm(X, y_numeric, type = svm_type, kernel = kernel, cost = cost, epsilon = epsilon)
    
    # Predict and synthesize Y(j)
    predictions <- predict(model, X)
    
    if (is.factor(y)) {
      # For factors, directly assign the predicted class
      data_synth[[var]] <- factor(predictions, levels = levels(y))
    } else {
      data_synth[[var]] <- predictions
    }
  }
  
  # Restore original factor levels and numeric types
  data_synth <- restore_factors_and_numeric(data, data_synth)
  
  return(data_synth)
}

# %% [markdown]
# ### Apply

# %%
cps_syndata <- synthesize_data_svm(cpspop, "sex")
# Out:
# [1] "Synthesizing variable: tax"
# [1] "Synthesizing variable: income"
# [1] "Synthesizing variable: csp"
# [1] "Synthesizing variable: age"
# [1] "Synthesizing variable: educ"
# [1] "Synthesizing variable: marital"
# [1] "Synthesizing variable: race"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘marital1’ and ‘marital2’ and ‘marital3’ and ‘marital4’ and ‘marital5’ and ‘marital6’ and ‘marital7’ constant. Cannot scale data.”
# [1] "Synthesizing variable: ss"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘marital1’ and ‘marital2’ and ‘marital3’ and ‘marital4’ and ‘marital5’ and ‘marital6’ and ‘marital7’ and ‘race2’ and ‘race3’ and ‘race4’ constant. Cannot scale data.”

# %%
adult_syndata <- synthesize_data_svm(adult, "sex")
# Out:
# [1] "Synthesizing variable: age"
# [1] "Synthesizing variable: workclass"
# [1] "Synthesizing variable: fnlwgt"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ constant. Cannot scale data.”
# [1] "Synthesizing variable: education"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ constant. Cannot scale data.”
# [1] "Synthesizing variable: marital_status"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ constant. Cannot scale data.”
# [1] "Synthesizing variable: occupation"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ constant. Cannot scale data.”
# [1] "Synthesizing variable: relationship"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ constant. Cannot scale data.”
# [1] "Synthesizing variable: race"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ and ‘relationship1’ and ‘relationship2’ and ‘relationship3’ and ‘relationship4’ and ‘relationship5’ constant. Cannot scale data.”
# [1] "Synthesizing variable: capital_gain"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ and ‘relationship1’ and ‘relationship2’ and ‘relationship3’ and ‘relationship4’ and ‘relationship5’ constant. Cannot scale data.”
# [1] "Synthesizing variable: capital_loss"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ and ‘relationship1’ and ‘relationship2’ and ‘relationship3’ and ‘relationship4’ and ‘relationship5’ constant. Cannot scale data.”
# [1] "Synthesizing variable: hours_per_week"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ and ‘relationship1’ and ‘relationship2’ and ‘relationship3’ and ‘relationship4’ and ‘relationship5’ constant. Cannot scale data.”
# [1] "Synthesizing variable: native_country"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ and ‘relationship1’ and ‘relationship2’ and ‘relationship3’ and ‘relationship4’ and ‘relationship5’ constant. Cannot scale data.”
# [1] "Synthesizing variable: income"
# Warning message in svm.default(x = X, y = y, type = type, kernel = kernel, cost = cost, :
# “Variable(s) ‘workclass0’ and ‘workclass1’ and ‘workclass2’ and ‘workclass3’ and ‘workclass4’ and ‘workclass5’ and ‘workclass6’ and ‘education1’ and ‘education2’ and ‘education3’ and ‘education4’ and ‘education5’ and ‘education6’ and ‘education7’ and ‘education8’ and ‘education9’ and ‘education10’ and ‘education11’ and ‘education12’ and ‘education13’ and ‘education14’ and ‘education15’ and ‘marital_status1’ and ‘marital_status2’ and ‘marital_status3’ and ‘marital_status4’ and ‘marital_status5’ and ‘marital_status6’ and ‘occupation1’ and ‘occupation2’ and ‘occupation4’ and ‘occupation5’ and ‘occupation6’ and ‘occupation7’ and ‘occupation8’ and ‘occupation9’ and ‘occupation11’ and ‘occupation12’ and ‘occupation13’ and ‘relationship1’ and ‘relationship2’ and ‘relationship3’ and ‘relationship4’ and ‘relationship5’ and ‘native_country1’ and ‘native_country2’ and ‘native_country3’ and ‘native_country4’ and ‘native_country5’ and ‘native_country6’ and ‘native_country7’ and ‘native_country8’ and ‘native_country9’ and ‘native_country10’ and ‘native_country11’ and ‘native_country12’ and ‘native_country13’ and ‘native_country14’ and ‘native_country15’ and ‘native_country16’ and ‘native_country17’ and ‘native_country18’ and ‘native_country19’ and ‘native_country20’ and ‘native_country21’ and ‘native_country22’ and ‘native_country23’ and ‘native_country24’ and ‘native_country25’ and ‘native_country26’ and ‘native_country27’ and ‘native_country28’ and ‘native_country29’ and ‘native_country30’ and ‘native_country31’ and ‘native_country32’ and ‘native_country33’ and ‘native_country34’ and ‘native_country35’ and ‘native_country36’ and ‘native_country37’ and ‘native_country38’ and ‘native_country39’ and ‘native_country40’ constant. Cannot scale data.”

# %% [markdown]
# ### Save results

# %%
write.csv(cps_syndata, file = paste0(directory, "/results/SVM_cps_syndata.csv"), row.names = FALSE)
write.csv(adult_syndata, file = paste0(directory, "/results/SVM_adult_syndata.csv"), row.names = FALSE)

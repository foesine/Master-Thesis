# %% [markdown]
# # MLP prediction function

# %% [markdown]
# ### Packages

# %%
list_of_packages <- c ("synthpop", "insight", "party", "dplyr", "rpart", "rpart.plot", "randomForest", "pROC", "caret", "pracma", "here", "Hmisc", "randomForest",  "xgboost", "data.table", "RSNNS", "nnet")

# Function to check and install packages
install_if_missing <- function(p) {
  if (!requireNamespace(p, quietly = TRUE)) {
    install.packages(p, dependencies = TRUE)
  }
  library(p, character.only = TRUE)
}

# Install and load all required packages
lapply(list_of_packages, install_if_missing)
# Out:
# Find out more at https://www.synthpop.org.uk/
#
# Lade n"otiges Paket: grid
#
# Lade n"otiges Paket: mvtnorm
#
# Lade n"otiges Paket: modeltools
#
# Lade n"otiges Paket: stats4
#
# Lade n"otiges Paket: strucchange
#
# Lade n"otiges Paket: zoo
#
#
# Attache Paket: 'zoo'
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     as.Date, as.Date.numeric
#
#
# Lade n"otiges Paket: sandwich
#
#
# Attache Paket: 'dplyr'
#
#
# Das folgende Objekt ist maskiert 'package:party':
#
#     where
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     filter, lag
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attache Paket: 'randomForest'
#
#
# Das folgende Objekt ist maskiert 'package:dplyr':
#
#     combine
#
#
# Type 'citation("pROC")' for a citation.
#
#
# Attache Paket: 'pROC'
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     cov, smooth, var
#
#
# Lade n"otiges Paket: ggplot2
#
#
# Attache Paket: 'ggplot2'
#
#
# Das folgende Objekt ist maskiert 'package:randomForest':
#
#     margin
#
#
# Lade n"otiges Paket: lattice
#
# here() starts at /Users/emmafoessing/Documents/Master/MA/Code/Master-Thesis
#
#
# Attache Paket: 'Hmisc'
#
#
# Das folgende Objekt ist maskiert 'package:pracma':
#
#     ceil
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     src, summarize
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     format.pval, units
#
#
#
# Attache Paket: 'xgboost'
#
#
# Das folgende Objekt ist maskiert 'package:dplyr':
#
#     slice
#
#
#
# Attache Paket: 'data.table'
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     between, first, last
#
#
# Die folgenden Objekte sind maskiert von 'package:zoo':
#
#     yearmon, yearqtr
#
#
# Lade n"otiges Paket: Rcpp
#
#
# Attache Paket: 'RSNNS'
#
#
# Die folgenden Objekte sind maskiert von 'package:caret':
#
#     confusionMatrix, train
# [[1]]
# [1] "synthpop"  "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
# [1] "insight"   "synthpop"  "stats"     "graphics"  "grDevices" "utils"
# [7] "datasets"  "methods"   "base"
#
# [[3]]
#  [1] "party"       "strucchange" "sandwich"    "zoo"         "modeltools"
#  [6] "stats4"      "mvtnorm"     "grid"        "insight"     "synthpop"
# [11] "stats"       "graphics"    "grDevices"   "utils"       "datasets"
# [16] "methods"     "base"
#
# [[4]]
#  [1] "dplyr"       "party"       "strucchange" "sandwich"    "zoo"
#  [6] "modeltools"  "stats4"      "mvtnorm"     "grid"        "insight"
# [11] "synthpop"    "stats"       "graphics"    "grDevices"   "utils"
# [16] "datasets"    "methods"     "base"
#
# [[5]]
#  [1] "rpart"       "dplyr"       "party"       "strucchange" "sandwich"
#  [6] "zoo"         "modeltools"  "stats4"      "mvtnorm"     "grid"
# [11] "insight"     "synthpop"    "stats"       "graphics"    "grDevices"
# [16] "utils"       "datasets"    "methods"     "base"
#
# [[6]]
#  [1] "rpart.plot"  "rpart"       "dplyr"       "party"       "strucchange"
#  [6] "sandwich"    "zoo"         "modeltools"  "stats4"      "mvtnorm"
# [11] "grid"        "insight"     "synthpop"    "stats"       "graphics"
# [16] "grDevices"   "utils"       "datasets"    "methods"     "base"
#
# [[7]]
#  [1] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
#  [6] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [11] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [16] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [21] "base"
#
# [[8]]
#  [1] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
#  [6] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [11] "stats4"       "mvtnorm"      "grid"         "insight"      "synthpop"
# [16] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [21] "methods"      "base"
#
# [[9]]
#  [1] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
#  [6] "rpart.plot"   "rpart"        "dplyr"        "party"        "strucchange"
# [11] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [16] "grid"         "insight"      "synthpop"     "stats"        "graphics"
# [21] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[10]]
#  [1] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
#  [6] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [11] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [16] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [21] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [26] "base"
#
# [[11]]
#  [1] "here"         "pracma"       "caret"        "lattice"      "ggplot2"
#  [6] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
# [11] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [16] "stats4"       "mvtnorm"      "grid"         "insight"      "synthpop"
# [21] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [26] "methods"      "base"
#
# [[12]]
#  [1] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
#  [6] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [11] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [16] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [21] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [26] "datasets"     "methods"      "base"
#
# [[13]]
#  [1] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
#  [6] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [11] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [16] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [21] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [26] "datasets"     "methods"      "base"
#
# [[14]]
#  [1] "xgboost"      "Hmisc"        "here"         "pracma"       "caret"
#  [6] "lattice"      "ggplot2"      "pROC"         "randomForest" "rpart.plot"
# [11] "rpart"        "dplyr"        "party"        "strucchange"  "sandwich"
# [16] "zoo"          "modeltools"   "stats4"       "mvtnorm"      "grid"
# [21] "insight"      "synthpop"     "stats"        "graphics"     "grDevices"
# [26] "utils"        "datasets"     "methods"      "base"
#
# [[15]]
#  [1] "data.table"   "xgboost"      "Hmisc"        "here"         "pracma"
#  [6] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
# [11] "rpart.plot"   "rpart"        "dplyr"        "party"        "strucchange"
# [16] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [21] "grid"         "insight"      "synthpop"     "stats"        "graphics"
# [26] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[16]]
#  [1] "RSNNS"        "Rcpp"         "data.table"   "xgboost"      "Hmisc"
#  [6] "here"         "pracma"       "caret"        "lattice"      "ggplot2"
# [11] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
# [16] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [21] "stats4"       "mvtnorm"      "grid"         "insight"      "synthpop"
# [26] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [31] "methods"      "base"
#
# [[17]]
#  [1] "nnet"         "RSNNS"        "Rcpp"         "data.table"   "xgboost"
#  [6] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
# [11] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [16] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [21] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [26] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [31] "datasets"     "methods"      "base"

# %% [markdown]
# ### Data

# %%
load(file = (paste0(here(), "/cpspop.RData")))
adult <- read.csv(file = (paste0(here(),"/adult_preprocessed.csv")))
# delete NAs
adult[adult == "?"] <- NA
adult <- na.omit(adult)

adult$workclass <- as.factor(adult$workclass)
adult$education <- as.factor(adult$education)
adult$marital_status <- as.factor(adult$marital_status)
adult$relationship <- as.factor(adult$relationship)
adult$race <- as.factor(adult$race)
adult$sex <- as.factor(adult$sex)
adult$native_country <- as.factor(adult$native_country)
adult$income <- as.factor(adult$income)

# %% [markdown]
# ### Helper functions

# %%
## eval cont targets
evaluation_metrics_cont <- function(predictions, test_set){
  MAE <- mean(abs(predictions - test_set$income))
  MSE <- mean((predictions - test_set$income)^2)
  RMSE <- sqrt(MSE)

  SS_res <- sum((test_set$income - predictions)^2)
  SS_tot <- sum((test_set$income - mean(test_set$income))^2)
  R_squared <- 1 - (SS_res / SS_tot)

  MAPE <- mean(abs((test_set$income - predictions) / test_set$income)) * 100

  # Create the dataframe
  metrics_df <- data.frame(
        MAE = MAE, 
        MSE = MSE, 
        RMSE = RMSE,
        R_squared = R_squared, 
        MAPE = MAPE)

  return(metrics_df)
}

# %%
## eval factored targets
evaluation_metrics_factor <- function(predictions, test_set){
    # confusion matrix for the prediction on original data
    cm <- confusionMatrix(predictions, test_set$income,
                mode = "everything")

    # saving evaluation metrics
    accuracy <- cm$overall['Accuracy']
    f1 <- cm$byClass['F1']
    sens <- cm$byClass['Sensitivity']
    spec <- cm$byClass['Specificity']

    # Create the dataframe
    metrics_df <- data.frame(
        Accuracy = accuracy, 
        F1 = f1, 
        Sensitivity = sens, 
        Specificity = spec
    )
    
    return(metrics_df)
}

# %%
mlp_pred <- function(data, outer_folds, size_steps, decay_steps, inner_folds){
    # adjust evaluation metric to fit both numeric and factored targets
    summaryFunctionType <- if (is.numeric(data$income)) defaultSummary else multiClassSummary
    # metric: train() uses per default RSME and Accuracy for numeric and factored targets

    #  set control args
    outer_control <- trainControl(method = "cv", number = outer_folds,
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)
        
    inner_control <- trainControl(method = "cv", number = inner_folds, 
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)

    # Define the grid for hyperparameter tuning
    size_values <- seq(1, 10, length.out = size_steps)
    decay_values <- 10^seq(log10(0.0001), log10(0.01), length.out = decay_steps)

    # Create grid
    tunegrid <- expand.grid(size = size_values, decay = decay_values)

    # Initialize variables to store results
    outer_results <- list()

    outer_cv_folds = createFolds(data$income, k = outer_folds)
    
    # Outer loop: Cross-validation for model evaluation
    for (i in seq_along(outer_folds)) {
        
        # Split data into outer folds
        outer_test_index = outer_cv_folds[[i]]
        outer_testData = data[outer_test_index,]
        outer_trainData  = data[-outer_test_index,]
        
        # Hyperparameter tuning using inner CV
        # No need for inner loop because "train" does k-fold CV already
        mlp_model <- caret::train(income ~ ., 
                           data = outer_trainData, 
                           method = "nnet", 
                           tuneGrid = tunegrid, 
                           trControl = inner_control)#,
                           #metric = metricType)
            

        # Store the best hyperparameters
        best_hyperparameters <- mlp_model$bestTune
        print("best HP")
        print(mlp_model$bestTune)

        # Train the final model on the outer training set with the best hyperparameters
        final_model <- caret::train(income ~ ., 
                             data = outer_trainData, 
                             method = "nnet", 
                             trControl = outer_control, 
                             tuneGrid = best_hyperparameters)

        # Testing the final model on the outer test set
        predictions <- predict(final_model, newdata = outer_testData)
        
        if (is.numeric(data$income)) {
            eval <- postResample(predictions, outer_testData$income) # postResample is a useful caret function
        } else if (is.factor(data$income)) {
            eval <- confusionMatrix(predictions, outer_testData$income)
        } else {
            stop("The predicted target has to be numeric or factor.")
        }

        # Store the evaluation metrics for this outer fold
        outer_results[[i]] <- eval
    }

    # Average the evaluation metrics over the outer folds
    eval_avg_outer_fold <- mean(unlist(outer_results)) # Calculate the mean performance over all outer folds

    # Return the average evaluation metrics
    return(eval_avg_outer_fold)
}

# %%
res <- mlp_pred(data = adult, outer_folds = 5, size_steps = 10, decay_steps = 10, inner_folds = 5)
# Out:
# # weights:  86
# initial  value 15394.690067
# iter  10 value 10822.179303
# final  value 10822.173596
# converged
# # weights:  171
# initial  value 10998.022953
# final  value 10777.589082
# converged
# # weights:  256
# initial  value 23482.429932
# final  value 10831.903831
# converged
# # weights:  341
# initial  value 16745.274127
# final  value 10798.506302
# converged
# # weights:  426
# initial  value 14362.514088
# iter  10 value 10822.189281
# final  value 10819.397986
# converged
# # weights:  511
# initial  value 16745.694159
# final  value 10777.642821
# converged
# # weights:  596
# initial  value 24571.985627
# iter  10 value 10690.843509
# final  value 10690.667192
# converged
# # weights:  681
# initial  value 29136.502647
# iter  10 value 10818.011610
# final  value 10818.010920
# converged
# # weights:  766
# initial  value 10965.759162
# final  value 10717.585007
# converged
# # weights:  851
# initial  value 20225.280082
# iter  10 value 10815.399515
# iter  20 value 10544.490542
# iter  30 value 9957.622489
# iter  40 value 9904.518365
# iter  50 value 9903.058737
# iter  60 value 9902.554835
# iter  70 value 9902.527758
# iter  80 value 9784.828505
# iter  90 value 9766.701406
# iter 100 value 9764.808709
# final  value 9764.808709
# stopped after 100 iterations
# # weights:  86
# initial  value 13970.724469
# final  value 10776.205568
# converged
# # weights:  171
# initial  value 11336.764398
# final  value 10831.904840
# converged
# # weights:  256
# initial  value 10787.801175
# iter  10 value 10010.796661
# iter  20 value 9985.868782
# iter  30 value 9984.427649
# iter  40 value 9982.424063
# iter  50 value 9980.038712
# iter  60 value 9979.970166
# iter  70 value 9979.962805
# iter  70 value 9979.962712
# iter  70 value 9979.962639
# final  value 9979.962639
# converged
# # weights:  341
# initial  value 14068.994058
# final  value 10831.909427
# converged
# # weights:  426
# initial  value 18023.401227
# iter  10 value 10818.013368
# iter  10 value 10818.013316
# iter  10 value 10818.013316
# final  value 10818.013316
# converged
# # weights:  511
# initial  value 11319.423257
# iter  10 value 10818.018540
# final  value 10811.054802
# converged
# # weights:  596
# initial  value 11253.584673
# final  value 10790.174545
# converged
# # weights:  681
# initial  value 11090.662123
# iter  10 value 10688.392815
# iter  20 value 10369.610501
# iter  30 value 10225.143985
# iter  40 value 10038.982739
# final  value 10038.970845
# converged
# # weights:  766
# initial  value 14496.567699
# final  value 10804.110154
# converged
# # weights:  851
# initial  value 10932.043637
# iter  10 value 10016.686116
# iter  20 value 10015.055473
# iter  20 value 10015.055382
# iter  20 value 10015.055382
# final  value 10015.055382
# converged
# # weights:  86
# initial  value 10845.703071
# iter  10 value 10798.532481
# iter  10 value 10798.532445
# iter  10 value 10798.532444
# final  value 10798.532444
# converged
# # weights:  171
# initial  value 13663.007000
# iter  10 value 10822.202720
# final  value 10822.200398
# converged
# # weights:  256
# initial  value 11109.387127
# iter  10 value 10759.461702
# final  value 10759.436863
# converged
# # weights:  341
# initial  value 12398.990252
# iter  10 value 10756.817716
# final  value 10717.392309
# converged
# # weights:  426
# initial  value 11250.126012
# iter  10 value 10761.222979
# final  value 10760.814900
# converged
# # weights:  511
# initial  value 12021.232384
# iter  10 value 10783.335817
# final  value 10783.182720
# converged
# # weights:  596
# initial  value 22815.869896
# iter  10 value 10786.133795
# final  value 10785.973211
# converged
# # weights:  681
# initial  value 15175.672033
# iter  10 value 10691.363712
# final  value 10690.693246
# converged
# # weights:  766
# initial  value 12251.802875
# iter  10 value 10677.833036
# iter  20 value 10676.447365
# iter  30 value 10676.414585
# iter  40 value 10215.253704
# iter  50 value 10018.938159
# iter  60 value 9854.719782
# iter  70 value 9645.921169
# iter  80 value 9500.218294
# iter  90 value 9059.186226
# iter 100 value 8357.881592
# final  value 8357.881592
# stopped after 100 iterations
# # weights:  851
# initial  value 14431.949814
# iter  10 value 10636.416954
# iter  20 value 10634.040179
# iter  30 value 10475.357356
# iter  40 value 10069.696342
# iter  50 value 10042.697306
# iter  60 value 10040.033264
# iter  70 value 9932.865036
# iter  80 value 9796.141304
# iter  90 value 9733.331325
# iter 100 value 9694.662667
# final  value 9694.662667
# stopped after 100 iterations
# # weights:  86
# initial  value 16640.364797
# final  value 10831.905711
# converged
# # weights:  171
# initial  value 14676.813514
# final  value 10241.762092
# converged
# # weights:  256
# initial  value 15555.103194
# iter  10 value 10463.581095
# iter  20 value 10022.827309
# iter  30 value 10022.691281
# iter  40 value 10014.764363
# iter  50 value 9991.238807
# iter  60 value 9985.988515
# iter  70 value 9981.711112
# iter  80 value 9976.747838
# iter  90 value 9966.212380
# iter 100 value 9949.619266
# final  value 9949.619266
# stopped after 100 iterations
# # weights:  341
# initial  value 13671.603320
# iter  10 value 10822.223575
# final  value 10822.222769
# converged
# # weights:  426
# initial  value 19924.561206
# iter  10 value 10815.268909
# final  value 10815.256073
# converged
# # weights:  511
# initial  value 11546.917903
# iter  10 value 10804.142783
# final  value 10804.127223
# converged
# # weights:  596
# initial  value 11141.174062
# iter  10 value 10787.410231
# final  value 10787.378886
# converged
# # weights:  681
# initial  value 11697.960244
# iter  10 value 10774.970976
# final  value 10774.801314
# converged
# # weights:  766
# initial  value 15116.929177
# iter  10 value 10816.686795
# iter  20 value 10816.645431
# final  value 10816.638421
# converged
# # weights:  851
# initial  value 13237.213923
# iter  10 value 10493.170747
# iter  20 value 10476.674581
# iter  30 value 10474.834158
# iter  40 value 10474.788451
# iter  50 value 9956.337919
# iter  60 value 9855.444903
# iter  70 value 9813.185391
# iter  80 value 9742.998426
# iter  90 value 9708.676531
# iter 100 value 9686.217404
# final  value 9686.217404
# stopped after 100 iterations
# # weights:  86
# initial  value 13046.009269
# iter  10 value 10476.465806
# iter  20 value 9889.099992
# iter  30 value 9776.173501
# iter  40 value 9676.901596
# iter  50 value 9627.556556
# iter  60 value 9601.856901
# iter  70 value 9593.208173
# iter  80 value 9590.328888
# iter  90 value 9587.407669
# iter 100 value 9585.324414
# final  value 9585.324414
# stopped after 100 iterations
# # weights:  171
# initial  value 13928.310715
# final  value 10831.921594
# converged
# # weights:  256
# initial  value 21027.671181
# iter  10 value 10683.106583
# iter  20 value 10654.435981
# iter  30 value 10141.760388
# final  value 10016.248894
# converged
# # weights:  341
# initial  value 12451.741254
# iter  10 value 10769.246297
# final  value 10769.245828
# converged
# # weights:  426
# initial  value 13119.841303
# iter  10 value 10811.135430
# iter  20 value 10792.996448
# iter  30 value 10553.356379
# iter  40 value 9924.791480
# iter  50 value 8926.514455
# iter  60 value 8099.100000
# iter  70 value 7696.146661
# iter  80 value 7500.853551
# iter  90 value 7231.427890
# iter 100 value 7147.631243
# final  value 7147.631243
# stopped after 100 iterations
# # weights:  511
# initial  value 12305.335338
# iter  10 value 10804.186938
# final  value 10804.138646
# converged
# # weights:  596
# initial  value 16850.956526
# iter  10 value 10605.448732
# iter  20 value 10605.408973
# iter  30 value 10031.620827
# iter  40 value 9894.501932
# iter  50 value 9830.650414
# iter  60 value 9824.281971
# iter  70 value 9771.299549
# iter  80 value 9768.510349
# iter  90 value 9768.161224
# iter 100 value 9764.088844
# final  value 9764.088844
# stopped after 100 iterations
# # weights:  681
# initial  value 27705.583835
# iter  10 value 10804.221226
# final  value 10804.129838
# converged
# # weights:  766
# initial  value 11433.158291
# iter  10 value 10815.348149
# iter  20 value 10615.570170
# iter  30 value 10155.633480
# iter  40 value 9973.218471
# iter  50 value 9954.078194
# iter  60 value 9847.573829
# iter  70 value 9811.884025
# iter  80 value 9806.712683
# iter  90 value 9786.502573
# iter 100 value 9699.750948
# final  value 9699.750948
# stopped after 100 iterations
# # weights:  851
# initial  value 11513.081394
# iter  10 value 10793.118657
# iter  20 value 10793.005133
# iter  30 value 10063.473040
# iter  40 value 9970.162535
# iter  50 value 9962.285510
# iter  60 value 9955.805983
# iter  70 value 9944.842300
# iter  80 value 9810.794030
# iter  90 value 9762.710439
# iter 100 value 9746.326561
# final  value 9746.326561
# stopped after 100 iterations
# # weights:  86
# initial  value 10843.413193
# iter  10 value 10820.910915
# iter  20 value 10820.898329
# iter  30 value 9845.723596
# iter  40 value 9720.524853
# iter  50 value 9699.486940
# iter  60 value 9690.707787
# iter  70 value 9689.273915
# iter  80 value 9675.615978
# iter  90 value 9634.655299
# iter 100 value 9595.102217
# final  value 9595.102217
# stopped after 100 iterations
# # weights:  171
# initial  value 11866.428718
# iter  10 value 10831.909072
# final  value 10831.900102
# converged
# # weights:  256
# initial  value 11006.099363
# iter  10 value 10818.168091
# iter  20 value 10818.123708
# iter  30 value 10016.110243
# iter  40 value 9996.611181
# iter  50 value 9885.384505
# iter  60 value 9777.984153
# iter  70 value 9659.749779
# iter  80 value 9625.725590
# iter  90 value 9600.233948
# iter 100 value 9593.561277
# final  value 9593.561277
# stopped after 100 iterations
# # weights:  341
# initial  value 11072.933446
# iter  10 value 10831.911549
# iter  20 value 10831.900090
# iter  20 value 10831.900087
# iter  20 value 10831.900087
# final  value 10831.900087
# converged
# # weights:  426
# initial  value 21236.913646
# iter  10 value 10816.720381
# iter  20 value 10812.983307
# iter  30 value 10346.579255
# iter  40 value 9879.936330
# iter  50 value 9226.641611
# iter  60 value 8022.332211
# iter  70 value 7683.321897
# iter  80 value 7616.679351
# iter  90 value 7612.603756
# iter 100 value 7572.034133
# final  value 7572.034133
# stopped after 100 iterations
# # weights:  511
# initial  value 26588.558365
# iter  10 value 10734.005248
# iter  20 value 10532.145526
# iter  30 value 10529.978164
# iter  40 value 10524.422830
# iter  50 value 10003.371514
# iter  60 value 9959.701290
# iter  70 value 9898.446401
# iter  80 value 9768.198883
# iter  90 value 9730.272401
# iter 100 value 9729.523071
# final  value 9729.523071
# stopped after 100 iterations
# # weights:  596

# %%
res
# Out:
# [1] NA

# %%
??mlpWeightDecay
# Out:
# No vignettes or demos or help files found with alias or concept or
# title matching 'mlpWeightDecay' using fuzzy matching.

# %% [markdown]
# # Just the MLP prediction

# %%
mlp_simulation <- function(data, nrun = 10, k_fold = 10, steps = 10){
  # Create empty list to store evaluation dataframes
  eval_list <- list()
  
  # Set initial seed
  s <- 1234
  
  for (i in 1:nrun){
    set.seed(s + i)
    
    # Define trainControl with k-fold cross-validation
    train_control <- trainControl(method = "cv", number = k_fold)
    
    # Define the grid for hyperparameter tuning
    size_values <- seq(1, 10, length.out = steps)
    decay_values <- 10^seq(log10(0.0001), log10(0.01), length.out = steps)
    
    # Create grid
    grid <- expand.grid(size = size_values, decay = decay_values)
    
    # Train the MLP model using caret with grid search
    mlp_model <- train(income ~ ., data = data, method = "nnet",
                       tuneGrid = grid, trControl = train_control, linout = TRUE, trace = FALSE)
    
    # Evaluation metrics
    predictions <- predict(mlp_model, newdata = data)
    
    if (is.numeric(data$income)) {
      eval <- as.data.frame(evaluation_metrics_cont(predictions, data$income))
    } else if (is.factor(data$income)) {
      eval <- as.data.frame(evaluation_metrics_factor(predictions, data$income))
    } else {
      stop("The predicted target has to be numeric or factor.")
    }
    
    eval_list[[i]] <- eval
    print(paste("run", i, "completed"))
  }
  
  # Average over all runs
  sum_df <- Reduce(function(x, y) Map(`+`, x, y), eval_list)
  eval_avg <- lapply(sum_df, function(col) col / length(eval_list))
  
  # Convert the list back to a dataframe
  # Store row names
  rownames <- row.names(eval_list[[1]])
  
  # Convert the list back to a dataframe
  eval_avg <- as.data.frame(eval_avg)
  
  # Set back the row names
  row.names(eval_avg) <- rownames
  
  # Returns
  results <- list(eval_avg = eval_avg)
  return(results)
}

# Example function for continuous evaluation metrics
evaluation_metrics_cont <- function(predictions, actuals) {
  mse <- mean((predictions - actuals)^2)
  rmse <- sqrt(mse)
  mae <- mean(abs(predictions - actuals))
  return(data.frame(MSE = mse, RMSE = rmse, MAE = mae))
}

# Example function for factor evaluation metrics
evaluation_metrics_factor <- function(predictions, actuals) {
  confusion <- confusionMatrix(predictions, actuals)
  accuracy <- confusion$overall['Accuracy']
  return(data.frame(Accuracy = accuracy))
}

# %%
cps_res <- mlp_simulation(cpspop)

# %%
adult_res <- mlp_simulation(adult)

# %% [markdown]
# ### Save the results

# %%
# Bind results
mlp_pred_results <- list(cps_res = cps_res, adult_res = adult_res)
# File pth for output
file <- "/user/emma.foessing01/u11969/results/mlp_pred_results.RData" 
dir.create(dirname(output_file), recursive = TRUE, showWarnings = FALSE) # create dir if not there
# Save the results to an RData file 
save(results, file = output_file)

# %% [markdown]
# # MLP prediction function

# %% [markdown]
# ### Packages

# %%
list_of_packages <- c ("synthpop", "insight", "party", "dplyr", "rpart", "rpart.plot", "randomForest", "pROC", "caret", "pracma", "here", "Hmisc", "randomForest",  "xgboost", "data.table", "RSNNS", "nnet")

# Function to check and install packages
install_if_missing <- function(p) {
  if (!requireNamespace(p, quietly = TRUE)) {
    install.packages(p, dependencies = TRUE)
  }
  library(p, character.only = TRUE)
}

# Install and load all required packages
lapply(list_of_packages, install_if_missing)
# Out:
# installiere auch Abh"angigkeiten 'scatterplot3d', 'NeuralNetTools'
# Die heruntergeladenen Bin"arpakete sind in
# 	/var/folders/kj/dkjqkk2n3wq2zfbttgdpjrj80000gn/T//RtmpfVfjzn/downloaded_packages
# Lade n"otiges Paket: Rcpp
#
#
# Attache Paket: 'RSNNS'
#
#
# Die folgenden Objekte sind maskiert von 'package:caret':
#
#     confusionMatrix, train
# [[1]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[2]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[3]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[4]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[5]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[6]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[7]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[8]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[9]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[10]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[11]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[12]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[13]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[14]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[15]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[16]]
#  [1] "nnet"         "data.table"   "xgboost"      "Hmisc"        "here"
#  [6] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
# [11] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [16] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [21] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [26] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [31] "base"
#
# [[17]]
#  [1] "RSNNS"        "Rcpp"         "nnet"         "data.table"   "xgboost"
#  [6] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
# [11] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [16] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [21] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [26] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [31] "datasets"     "methods"      "base"

# %% [markdown]
# ### Data

# %%
load(file = (paste0(here(), "/cpspop.RData")))
adult <- read.csv(file = (paste0(here(),"/adult_preprocessed.csv")))
# delete NAs
adult[adult == "?"] <- NA
adult <- na.omit(adult)

adult$workclass <- as.factor(adult$workclass)
adult$education <- as.factor(adult$education)
adult$marital_status <- as.factor(adult$marital_status)
adult$relationship <- as.factor(adult$relationship)
adult$race <- as.factor(adult$race)
adult$sex <- as.factor(adult$sex)
adult$native_country <- as.factor(adult$native_country)
adult$income <- as.factor(adult$income)

# %% [markdown]
# ### Helper functions

# %%
## eval cont targets
evaluation_metrics_cont <- function(predictions, test_set){
  MAE <- mean(abs(predictions - test_set$income))
  MSE <- mean((predictions - test_set$income)^2)
  RMSE <- sqrt(MSE)

  SS_res <- sum((test_set$income - predictions)^2)
  SS_tot <- sum((test_set$income - mean(test_set$income))^2)
  R_squared <- 1 - (SS_res / SS_tot)

  MAPE <- mean(abs((test_set$income - predictions) / test_set$income)) * 100

  # Create the dataframe
  metrics_df <- data.frame(
        MAE = MAE, 
        MSE = MSE, 
        RMSE = RMSE,
        R_squared = R_squared, 
        MAPE = MAPE)

  return(metrics_df)
}

# %%
## eval factored targets
evaluation_metrics_factor <- function(predictions, test_set){
    # confusion matrix for the prediction on original data
    cm <- confusionMatrix(predictions, test_set$income,
                mode = "everything")

    # saving evaluation metrics
    accuracy <- cm$overall['Accuracy']
    f1 <- cm$byClass['F1']
    sens <- cm$byClass['Sensitivity']
    spec <- cm$byClass['Specificity']

    # Create the dataframe
    metrics_df <- data.frame(
        Accuracy = accuracy, 
        F1 = f1, 
        Sensitivity = sens, 
        Specificity = spec
    )
    
    return(metrics_df)
}

# %%
mlp_pred <- function(data, outer_folds, size_steps, decay_steps, inner_folds){
    # adjust evaluation metric to fit both numeric and factored targets
    summaryFunctionType <- if (is.numeric(data$income)) defaultSummary else multiClassSummary
    # metric: train() uses per default RSME and Accuracy for numeric and factored targets

    #  set control args
    outer_control <- trainControl(method = "cv", number = outer_folds,
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)
        
    inner_control <- trainControl(method = "cv", number = inner_folds, 
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)

    # Define the grid for hyperparameter tuning
    size_values <- seq(1, 10, length.out = size_steps)
    decay_values <- 10^seq(log10(0.0001), log10(0.01), length.out = decay_steps)

    # Create grid
    tunegrid <- expand.grid(size = size_values, decay = decay_values)

    # Initialize variables to store results
    outer_results <- list()

    outer_cv_folds = createFolds(data$income, k = outer_folds)
    
    # Outer loop: Cross-validation for model evaluation
    for (i in seq_along(outer_folds)) {
        
        # Split data into outer folds
        outer_test_index = outer_cv_folds[[i]]
        outer_testData = data[outer_test_index,]
        outer_trainData  = data[-outer_test_index,]
        
        # Hyperparameter tuning using inner CV
        # No need for inner loop because "train" does k-fold CV already
        mlp_model <- caret::train(income ~ ., 
                           data = outer_trainData, 
                           method = "nnet", 
                           tuneGrid = tunegrid, 
                           trControl = inner_control)#,
                           #metric = metricType)
            

        # Store the best hyperparameters
        best_hyperparameters <- mlp_model$bestTune
        print("best HP")
        print(mlp_model$bestTune)

        # Train the final model on the outer training set with the best hyperparameters
        final_model <- caret::train(income ~ ., 
                             data = outer_trainData, 
                             method = "nnet", 
                             trControl = outer_control, 
                             tuneGrid = best_hyperparameters)

        # Testing the final model on the outer test set
        predictions <- predict(final_model, newdata = outer_testData)
        
        if (is.numeric(data$income)) {
            eval <- postResample(predictions, outer_testData$income) # postResample is a useful caret function
        } else if (is.factor(data$income)) {
            eval <- confusionMatrix(predictions, outer_testData$income)
        } else {
            stop("The predicted target has to be numeric or factor.")
        }

        # Store the evaluation metrics for this outer fold
        outer_results[[i]] <- eval
    }

    # Average the evaluation metrics over the outer folds
    eval_avg_outer_fold <- mean(unlist(outer_results)) # Calculate the mean performance over all outer folds

    # Return the average evaluation metrics
    return(eval_avg_outer_fold)
}

# %%
mlp_pred(data = cpspop, outer_folds = 5, size_steps = 10, decay_steps = 10, inner_folds = 5)
# Out:
# # weights:  32
# initial  value 169990613657967.625000
# final  value 169989129590692.687500
# converged
# # weights:  63
# initial  value 169991276907728.312500
# final  value 169989129595525.187500
# converged
# # weights:  94
# initial  value 169990856113409.468750
# final  value 169989129595998.531250
# converged
# # weights:  125
# initial  value 169991388881218.812500
# final  value 169989129598763.500000
# converged
# # weights:  156
# initial  value 169990513126694.812500
# final  value 169989129579700.656250
# converged
# # weights:  187
# initial  value 169991369892264.125000
# final  value 169989129601918.562500
# converged
# # weights:  218
# initial  value 169991473376007.437500
# final  value 169989129606472.718750
# converged
# # weights:  249
# initial  value 169990263034419.375000
# final  value 169989129580074.312500
# converged
# # weights:  280
# initial  value 169990817718357.062500
# final  value 169989129578986.062500
# converged
# # weights:  311
# initial  value 169991637746693.281250
# final  value 169989129580566.281250
# converged
# # weights:  32
# initial  value 169991016902410.781250
# final  value 169989129598730.500000
# converged
# # weights:  63
# initial  value 169991272945342.218750
# final  value 169989129601762.312500
# converged
# # weights:  94
# initial  value 169990638376706.500000
# final  value 169989129579690.125000
# converged
# # weights:  125
# initial  value 169990648514883.906250
# final  value 169989129580524.656250
# converged
# # weights:  156
# initial  value 169991400023855.250000
# final  value 169989129579373.437500
# converged
# # weights:  187
# initial  value 169991085122623.375000
# final  value 169989129580115.812500
# converged
# # weights:  218
# initial  value 169991470110826.500000
# final  value 169989129581413.062500
# converged
# # weights:  249
# initial  value 169990468005089.812500
# final  value 169989129581999.968750
# converged
# # weights:  280
# initial  value 169990870416762.625000
# final  value 169989129582374.406250
# converged
# # weights:  311
# initial  value 169990380153218.187500
# final  value 169989129581402.875000
# converged
# # weights:  32
# initial  value 169990533318326.750000
# final  value 169989129610964.375000
# converged
# # weights:  63
# initial  value 169989975463347.937500
# final  value 169989129580563.312500
# converged
# # weights:  94
# initial  value 169991737726679.031250
# final  value 169989129631249.906250
# converged
# # weights:  125
# initial  value 169991350903199.781250
# final  value 169989129582151.218750
# converged
# # weights:  156
# initial  value 169990587507523.125000
# final  value 169989129582049.750000
# converged
# # weights:  187
# initial  value 169991397309121.875000
# final  value 169989129583186.593750
# converged
# # weights:  218
# initial  value 169991311214284.875000
# final  value 169989129584870.406250
# converged
# # weights:  249
# initial  value 169989917768305.468750
# final  value 169989129581783.093750
# converged
# # weights:  280
# initial  value 169991754434978.562500
# final  value 169989129580246.187500
# converged
# # weights:  311
# initial  value 169990652132076.250000
# final  value 169989129582005.593750
# converged
# # weights:  32
# initial  value 169991461054241.906250
# final  value 169989129659400.125000
# converged
# # weights:  63
# initial  value 169990968512495.500000
# final  value 169989129669668.968750
# converged
# # weights:  94
# initial  value 169990115476371.312500
# final  value 169989129582571.031250
# converged
# # weights:  125
# initial  value 169990555093816.156250
# final  value 169989129582694.906250
# converged
# # weights:  156
# initial  value 169990993058334.875000
# final  value 169989129586221.531250
# converged
# # weights:  187
# initial  value 169990558568153.093750
# final  value 169989129584766.312500
# converged
# # weights:  218
# initial  value 169990122011475.406250
# final  value 169989129585403.906250
# converged
# # weights:  249
# initial  value 169991100003168.312500
# final  value 169989129592237.781250
# converged
# # weights:  280
# initial  value 169990400134179.687500
# final  value 169989129582252.562500
# converged
# # weights:  311
# initial  value 169991609572934.437500
# final  value 169989129585777.875000
# converged
# # weights:  32
# initial  value 169990650148415.375000
# final  value 169989129673471.531250
# converged
# # weights:  63
# initial  value 169990789636427.093750
# final  value 169989129699962.312500
# converged
# # weights:  94
# initial  value 169990750593465.125000
# final  value 169989129589419.750000
# converged
# # weights:  125
# initial  value 169990518789530.750000
# final  value 169989129590102.187500
# converged
# # weights:  156
# initial  value 169991743870268.437500
# final  value 169989129731342.843750
# converged
# # weights:  187
# initial  value 169990842175969.562500
# final  value 169989129586707.343750
# converged
# # weights:  218
# initial  value 169989997965630.031250
# final  value 169989129584820.812500
# converged
# # weights:  249
# initial  value 169991243759954.656250
# final  value 169989129588194.531250
# converged
# # weights:  280
# initial  value 169990483043942.375000
# final  value 169989129599309.187500
# converged
# # weights:  311
# initial  value 169989386938811.812500
# final  value 169989129580841.937500
# converged
# # weights:  32
# initial  value 169990918912387.468750
# final  value 169989129736625.593750
# converged
# # weights:  63
# initial  value 169990681149049.593750
# final  value 169989129593134.187500
# converged
# # weights:  94
# initial  value 169990211594181.062500
# final  value 169989129589068.625000
# converged
# # weights:  125
# initial  value 169990599088375.406250
# final  value 169989129813482.343750
# converged
# # weights:  156
# initial  value 169991363918590.312500
# final  value 169989129604703.531250
# converged
# # weights:  187
# initial  value 169991024793954.125000
# final  value 169989129636746.062500
# converged
# # weights:  218
# initial  value 169991416522087.281250
# final  value 169989129597113.906250
# converged
# # weights:  249
# initial  value 169991300376533.781250
# final  value 169989129603626.343750
# converged
# # weights:  280
# initial  value 169991177812212.218750
# final  value 169989129597148.031250
# converged
# # weights:  311
# initial  value 169990166354443.843750
# final  value 169989129582801.843750
# converged
# # weights:  32
# initial  value 169990646128448.093750
# final  value 169989129934421.093750
# converged
# # weights:  63
# initial  value 169991718689913.375000
# final  value 169989129982902.750000
# converged
# # weights:  94
# initial  value 169990918120197.625000
# final  value 169989130019820.468750
# converged
# # weights:  125
# initial  value 169990508728743.906250
# final  value 169989129610208.500000
# converged
# # weights:  156
# initial  value 169991088369146.062500
# final  value 169989129614066.781250
# converged
# # weights:  187
# initial  value 169991416946339.906250
# final  value 169989129605418.562500
# converged
# # weights:  218
# initial  value 169990149533989.250000
# final  value 169989129597959.468750
# converged
# # weights:  249
# initial  value 169991973560547.625000
# final  value 169989130122709.718750
# converged
# # weights:  280
# initial  value 169990701945830.125000
# final  value 169989129620951.406250
# converged
# # weights:  311
# initial  value 169990369507632.218750
# final  value 169989129624440.312500
# converged
# # weights:  32
# initial  value 169991228880450.375000
# final  value 169989129960937.531250
# converged
# # weights:  63
# initial  value 169991542392785.062500
# final  value 169989129987866.906250
# converged
# # weights:  94
# initial  value 169990785545979.625000
# final  value 169989129728733.187500
# converged
# # weights:  125
# initial  value 169991600531160.687500
# final  value 169989130048883.437500
# converged
# # weights:  156
# initial  value 169990708575909.406250
# final  value 169989129623546.812500
# converged
# # weights:  187
# initial  value 169991537498830.093750
# final  value 169989130145625.906250
# converged
# # weights:  218
# initial  value 169991502940827.906250
# final  value 169989130598780.562500
# converged
# # weights:  249
# initial  value 169991225974733.562500
# final  value 169989129661308.093750
# converged
# # weights:  280
# initial  value 169990982139248.875000
# final  value 169989129632189.093750
# converged
# # weights:  311
# initial  value 169992074450247.812500
# final  value 169989130056106.125000
# converged
# # weights:  32
# initial  value 169990955812014.281250
# final  value 169989130785263.812500
# converged
# # weights:  63
# initial  value 169990776482106.968750
# final  value 169989130695139.031250
# converged
# # weights:  94
# initial  value 169991135697278.125000
# final  value 169989130370339.250000
# converged
# # weights:  125
# initial  value 169990385181935.843750
# final  value 169989130378634.218750
# converged
# # weights:  156
# initial  value 169990836485123.343750
# final  value 169989129674804.250000
# converged
# # weights:  187
# initial  value 169990139159329.687500
# final  value 169989129638638.625000
# converged
# # weights:  218
# initial  value 169990687275538.218750
# final  value 169989129697679.031250
# converged
# # weights:  249
# initial  value 169990033020730.281250
# final  value 169989129633330.406250
# converged
# # weights:  280
# initial  value 169990238114848.500000
# final  value 169989129717992.562500
# converged
# # weights:  311
# initial  value 169991539455353.062500
# final  value 169989129620702.718750
# converged
# # weights:  32
# initial  value 169991017464313.468750
# final  value 169989131352158.406250
# converged
# # weights:  63
# initial  value 169991062793490.562500
# final  value 169989131200020.000000
# converged
# # weights:  94
# initial  value 169991186782473.250000
# final  value 169989129683787.375000
# converged
# # weights:  125
# initial  value 169990248106632.968750
# final  value 169989129665295.750000
# converged
# # weights:  156
# initial  value 169989844102569.250000
# final  value 169989129680807.375000
# converged
# # weights:  187
# initial  value 169991742833258.406250
# final  value 169989130893033.031250
# converged
# # weights:  218
# initial  value 169991135459164.500000
# final  value 169989129774206.593750
# converged
# # weights:  249
# initial  value 169990435241964.187500
# final  value 169989129669608.312500
# converged
# # weights:  280
# initial  value 169991027974879.437500
# final  value 169989129771387.406250
# converged
# # weights:  311
# initial  value 169989961542035.750000
# final  value 169989129585391.718750
# converged
# # weights:  32
# initial  value 169322893550988.937500
# final  value 169321125575496.062500
# converged
# # weights:  63
# initial  value 169323142063749.718750
# final  value 169321125587195.312500
# converged
# # weights:  94
# initial  value 169323049353923.906250
# final  value 169321125586128.875000
# converged
# # weights:  125
# initial  value 169323695624769.843750
# final  value 169321125578296.781250
# converged
# # weights:  156
# initial  value 169322109558904.062500
# final  value 169321125564308.500000
# converged
# # weights:  187
# initial  value 169322556696129.125000
# final  value 169321125565482.312500
# converged
# # weights:  218
# initial  value 169323296801238.843750
# final  value 169321125565460.093750
# converged
# # weights:  249
# initial  value 169322761247216.937500
# final  value 169321125565809.343750
# converged
# # weights:  280
# initial  value 169323503295806.281250
# final  value 169321125565952.875000
# converged
# # weights:  311
# initial  value 169323136967357.687500
# final  value 169321125564335.718750
# converged
# # weights:  32
# initial  value 169322654935644.187500
# final  value 169321125565080.656250
# converged
# # weights:  63
# initial  value 169322228051927.500000
# final  value 169321125564947.500000
# converged
# # weights:  94
# initial  value 169322899739012.343750
# final  value 169321125596693.062500
# converged
# # weights:  125
# initial  value 169322924929895.093750
# final  value 169321125563824.937500
# converged
# # weights:  156
# initial  value 169322610876653.031250
# final  value 169321125565610.562500
# converged
# # weights:  187
# initial  value 169322761176943.562500
# final  value 169321125563759.656250
# converged
# # weights:  218
# initial  value 169322977452755.718750
# final  value 169321125565695.093750
# converged
# # weights:  249
# initial  value 169323723649303.531250
# final  value 169321125594059.875000
# converged
# # weights:  280
# initial  value 169322114394020.187500
# final  value 169321125566552.687500
# converged
# # weights:  311
# initial  value 169322555997328.000000
# final  value 169321125567711.937500
# converged
# # weights:  32
# initial  value 169322805098601.812500
# final  value 169321125600458.593750
# converged
# # weights:  63
# initial  value 169322602193383.062500
# final  value 169321125563620.093750
# converged
# # weights:  94
# initial  value 169323406305323.562500
# final  value 169321125564062.375000
# converged
# # weights:  125
# initial  value 169322238227787.718750
# final  value 169321125568007.093750
# converged
# # weights:  156
# initial  value 169322511990413.625000
# final  value 169321125566933.468750
# converged
# # weights:  187
# initial  value 169323188085631.343750
# final  value 169321125568265.781250
# converged
# # weights:  218
# initial  value 169322607428766.031250
# final  value 169321125564260.281250
# converged
# # weights:  249
# initial  value 169322987552851.531250
# final  value 169321125568795.406250
# converged
# # weights:  280
# initial  value 169323117878951.875000
# final  value 169321125570718.843750
# converged
# # weights:  311
# initial  value 169323626970499.906250
# final  value 169321125564570.875000
# converged
# # weights:  32
# initial  value 169322352926471.250000
# final  value 169321125569648.468750
# converged
# # weights:  63
# initial  value 169323112479588.093750
# final  value 169321125654267.625000
# converged
# # weights:  94
# initial  value 169322890440084.031250
# final  value 169321125622329.875000
# converged
# # weights:  125
# initial  value 169322776478836.531250
# final  value 169321125569927.531250
# converged
# # weights:  156
# initial  value 169323404111502.000000
# final  value 169321125660661.406250
# converged
# # weights:  187
# initial  value 169323445594785.843750
# final  value 169321125615655.687500
# converged
# # weights:  218
# initial  value 169323286329817.906250
# final  value 169321125585025.250000
# converged
# # weights:  249
# initial  value 169323056493873.156250
# final  value 169321125572258.937500
# converged
# # weights:  280
# initial  value 169322729831936.468750
# final  value 169321125573917.937500
# converged
# # weights:  311
# initial  value 169322094274577.250000
# final  value 169321125570547.468750
# converged
# # weights:  32
# initial  value 169322885353576.343750
# final  value 169321125719707.156250
# converged
# # weights:  63
# initial  value 169323006687907.093750
# final  value 169321125721297.468750
# converged
# # weights:  94
# initial  value 169323214461361.156250
# final  value 169321125682306.406250
# converged
# # weights:  125
# initial  value 169322899477009.000000
# final  value 169321125570865.562500
# converged
# # weights:  156
# initial  value 169322273242549.625000
# final  value 169321125575820.031250
# converged
# # weights:  187
# initial  value 169323466790298.593750
# final  value 169321125576160.562500
# converged
# # weights:  218
# initial  value 169323197140481.250000
# final  value 169321125573572.500000
# converged
# # weights:  249
# initial  value 169321887698024.281250
# final  value 169321125572861.687500
# converged
# # weights:  280
# initial  value 169322765156361.062500
# final  value 169321125578576.781250
# converged
# # weights:  311
# initial  value 169323696567751.656250
# final  value 169321125782225.468750
# converged
# # weights:  32
# initial  value 169322295519321.000000
# final  value 169321125690628.312500
# converged
# # weights:  63
# initial  value 169322973178622.000000
# final  value 169321125734456.906250
# converged
# # weights:  94
# initial  value 169322810732461.437500
# final  value 169321125574768.937500
# converged
# # weights:  125
# initial  value 169322561160834.593750
# final  value 169321125727162.000000
# converged
# # weights:  156
# initial  value 169323316590495.937500
# final  value 169321125620473.468750
# converged
# # weights:  187
# initial  value 169322797324228.906250
# final  value 169321125586717.031250
# converged
# # weights:  218
# initial  value 169323628620029.781250
# final  value 169321125821589.187500
# converged
# # weights:  249
# initial  value 169322641330534.812500
# final  value 169321125583804.312500
# converged
# # weights:  280
# initial  value 169323162700338.156250
# final  value 169321125586021.343750
# converged
# # weights:  311
# initial  value 169323383838413.093750
# final  value 169321125568904.468750
# converged
# # weights:  32
# initial  value 169322322916183.843750
# final  value 169321125775756.031250
# converged
# # weights:  63
# initial  value 169323008380116.781250
# final  value 169321125983800.218750
# converged
# # weights:  94
# initial  value 169322629578548.312500
# final  value 169321125589358.343750
# converged
# # weights:  125
# initial  value 169322968823545.156250
# final  value 169321125651212.437500
# converged
# # weights:  156
# initial  value 169322287733615.906250
# final  value 169321125566374.375000
# converged
# # weights:  187
# initial  value 169322051680867.156250
# final  value 169321125584551.593750
# converged
# # weights:  218
# initial  value 169323275326282.968750
# final  value 169321125589512.250000
# converged
# # weights:  249
# initial  value 169322876980988.812500
# final  value 169321125600446.375000
# converged
# # weights:  280
# initial  value 169323023824762.781250
# final  value 169321125664116.187500
# converged
# # weights:  311
# initial  value 169323168824035.593750
# final  value 169321125635695.093750
# converged
# # weights:  32
# initial  value 169322671396693.093750
# final  value 169321125990277.562500
# converged
# # weights:  63
# initial  value 169322719433386.375000
# final  value 169321125564278.187500
# converged
# # weights:  94
# initial  value 169322948211543.968750
# final  value 169321125610635.937500
# converged
# # weights:  125
# initial  value 169322670350250.125000
# final  value 169321125592700.875000
# converged
# # weights:  156
# initial  value 169322321178827.187500
# final  value 169321125590205.593750
# converged
# # weights:  187
# initial  value 169321902093246.062500
# final  value 169321125617798.562500
# converged
# # weights:  218
# initial  value 169322519797214.812500
# final  value 169321125625299.156250
# converged
# # weights:  249
# initial  value 169323778228274.531250
# final  value 169321126312876.625000
# converged
# # weights:  280
# initial  value 169323426750548.312500
# final  value 169321125607413.656250
# converged
# # weights:  311
# initial  value 169321717498501.843750
# final  value 169321125591525.375000
# converged
# # weights:  32
# initial  value 169322536254334.625000
# final  value 169321125616366.312500
# converged
# # weights:  63
# initial  value 169322366092598.156250
# final  value 169321125647738.375000
# converged
# # weights:  94
# initial  value 169322549213793.031250
# final  value 169321125647324.343750
# converged
# # weights:  125
# initial  value 169322038942527.406250
# final  value 169321125597620.468750
# converged
# # weights:  156
# initial  value 169322465976991.718750
# final  value 169321125685826.375000
# converged
# # weights:  187
# initial  value 169323063689912.812500
# final  value 169321125646694.781250
# converged
# # weights:  218
# initial  value 169323236286554.343750
# final  value 169321125682576.812500
# converged
# # weights:  249
# initial  value 169322367700958.375000
# final  value 169321125649544.250000
# converged
# # weights:  280
# initial  value 169322566304954.156250
# final  value 169321125740390.625000
# converged
# # weights:  311
# initial  value 169322192472754.718750
# final  value 169321125570607.062500
# converged
# # weights:  32
# initial  value 169322278921041.187500
# final  value 169321125631465.312500
# converged
# # weights:  63
# initial  value 169323272413886.656250
# final  value 169321125799699.281250
# converged
# # weights:  94
# initial  value 169322565729037.937500
# final  value 169321127081721.062500
# converged
# # weights:  125
# initial  value 169323727308872.000000
# final  value 169321128332964.437500
# converged
# # weights:  156
# initial  value 169322807411912.781250
# final  value 169321125690642.625000
# converged
# # weights:  187
# initial  value 169322674633201.750000
# final  value 169321125692522.000000
# converged
# # weights:  218
# initial  value 169323353583418.593750
# final  value 169321125596939.625000
# converged
# # weights:  249
# initial  value 169322497704710.343750
# final  value 169321125701398.718750
# converged
# # weights:  280
# initial  value 169322091606900.500000
# final  value 169321125737103.843750
# converged
# # weights:  311
# initial  value 169323134430160.593750
# final  value 169321125759803.062500
# converged
# # weights:  32
# initial  value 169961246826127.906250
# final  value 169958868779936.656250
# converged
# # weights:  63
# initial  value 169960638851135.812500
# final  value 169958868790686.531250
# converged
# # weights:  94
# initial  value 169961162514334.375000
# final  value 169958868789611.468750
# converged
# # weights:  125
# initial  value 169961132184374.000000
# final  value 169958868794280.500000
# converged
# # weights:  156
# initial  value 169960745208043.781250
# final  value 169958868771916.625000
# converged
# # weights:  187
# initial  value 169959956177883.437500
# final  value 169958868771086.406250
# converged
# # weights:  218
# initial  value 169960140520152.343750
# final  value 169958868771833.218750
# converged
# # weights:  249
# initial  value 169960792094921.093750
# final  value 169958868772188.093750
# converged
# # weights:  280
# initial  value 169960804368269.593750
# final  value 169958868772478.625000
# converged
# # weights:  311
# initial  value 169961284351605.437500
# final  value 169958868771894.093750
# converged
# # weights:  32
# initial  value 169961011312615.468750
# final  value 169958868788245.937500
# converged
# # weights:  63
# initial  value 169960399103221.562500
# final  value 169958868791465.031250
# converged
# # weights:  94
# initial  value 169960688974445.593750
# final  value 169958868773933.812500
# converged
# # weights:  125
# initial  value 169959819722877.875000
# final  value 169958868771821.656250
# converged
# # weights:  156
# initial  value 169960293149695.812500
# final  value 169958868772217.781250
# converged
# # weights:  187
# initial  value 169960927207276.750000
# final  value 169958868772921.625000
# converged
# # weights:  218
# initial  value 169961328297951.875000
# final  value 169958868772754.500000
# converged
# # weights:  249
# initial  value 169959714837319.062500
# final  value 169958868774020.781250
# converged
# # weights:  280
# initial  value 169960353656519.875000
# final  value 169958868770989.781250
# converged
# # weights:  311
# initial  value 169960410993719.593750
# final  value 169958868770619.468750
# converged
# # weights:  32
# initial  value 169961304964888.093750
# final  value 169958868806693.281250
# converged
# # weights:  63
# initial  value 169960387325300.218750
# final  value 169958868804430.968750
# converged
# # weights:  94
# initial  value 169960325312670.718750
# final  value 169958868813272.187500
# converged
# # weights:  125
# initial  value 169960679222251.312500
# final  value 169958868774461.781250
# converged
# # weights:  156
# initial  value 169961209712251.843750
# final  value 169958868840615.687500
# converged
# # weights:  187
# initial  value 169960791382976.812500
# final  value 169958868773384.281250
# converged
# # weights:  218
# initial  value 169960945811771.281250
# final  value 169958868780866.593750
# converged
# # weights:  249
# initial  value 169960462883478.687500
# final  value 169958868775514.687500
# converged
# # weights:  280
# initial  value 169961471765177.406250
# final  value 169958868770827.593750
# converged
# # weights:  311
# initial  value 169960413287572.750000
# final  value 169958868778808.812500
# converged
# # weights:  32
# initial  value 169959775320365.812500
# final  value 169958868772781.843750
# converged
# # weights:  63
# initial  value 169959610778085.750000
# final  value 169958868772968.656250
# converged
# # weights:  94
# initial  value 169960528904551.625000
# final  value 169958868855701.031250
# converged
# # weights:  125
# initial  value 169960498337296.093750
# final  value 169958868777289.062500
# converged
# # weights:  156
# initial  value 169960325480239.718750
# final  value 169958868777023.156250
# converged
# # weights:  187
# initial  value 169960629566293.187500
# final  value 169958868776898.031250
# converged
# # weights:  218
# initial  value 169961235041540.250000
# final  value 169958868776275.250000
# converged
# # weights:  249
# initial  value 169960753277511.531250
# final  value 169958868772355.437500
# converged
# # weights:  280
# initial  value 169961745992177.375000
# final  value 169958868883961.375000
# converged
# # weights:  311
# initial  value 169960313940929.593750
# final  value 169958868781966.687500
# converged
# # weights:  32
# initial  value 169960339763210.406250
# final  value 169958868861558.218750
# converged
# # weights:  63
# initial  value 169960407736151.656250
# final  value 169958868781113.062500
# converged
# # weights:  94
# initial  value 169960049581758.000000
# final  value 169958868777854.843750
# converged
# # weights:  125
# initial  value 169960972456245.968750
# final  value 169958868784496.062500
# converged
# # weights:  156
# initial  value 169960724962005.093750
# final  value 169958868781605.781250
# converged
# # weights:  187
# initial  value 169961330267857.812500
# final  value 169958868781445.593750
# converged
# # weights:  218
# initial  value 169960892318107.937500
# final  value 169958868929675.156250
# converged
# # weights:  249
# initial  value 169961432748693.406250
# final  value 169958868915609.656250
# converged
# # weights:  280
# initial  value 169961037516519.593750
# final  value 169958868981812.062500
# converged
# # weights:  311
# initial  value 169961609842001.781250
# final  value 169958868975736.031250
# converged
# # weights:  32
# initial  value 169960274287771.125000
# final  value 169958868781951.218750
# converged
# # weights:  63
# initial  value 169960524399953.656250
# final  value 169958868787396.281250
# converged
# # weights:  94
# initial  value 169961219216405.281250
# final  value 169958868994279.375000
# converged
# # weights:  125
# initial  value 169960545728153.500000
# final  value 169958868787908.187500
# converged
# # weights:  156
# initial  value 169960926862836.406250
# final  value 169958868792787.250000
# converged
# # weights:  187
# initial  value 169960263096503.531250
# final  value 169958868787320.312500
# converged
# # weights:  218
# initial  value 169961443978638.312500
# final  value 169958869013316.531250
# converged
# # weights:  249
# initial  value 169960725209860.218750
# final  value 169958868803457.343750
# converged
# # weights:  280
# initial  value 169960837966563.687500
# final  value 169958868793167.812500
# converged
# # weights:  311
# initial  value 169959814974202.687500
# final  value 169958868787056.125000
# converged
# # weights:  32
# initial  value 169960771040038.968750
# final  value 169958869036962.312500
# converged
# # weights:  63
# initial  value 169960308902455.968750
# final  value 169958868794185.812500
# converged
# # weights:  94
# initial  value 169959694688280.218750
# final  value 169958868782626.968750
# converged
# # weights:  125
# initial  value 169960794414340.187500
# final  value 169958868799465.812500
# converged
# # weights:  156
# initial  value 169961051094397.781250
# final  value 169958868771772.312500
# converged
# # weights:  187
# initial  value 169959853495474.375000
# final  value 169958868792424.687500
# converged
# # weights:  218
# initial  value 169961296852219.781250
# final  value 169958869384582.593750
# converged
# # weights:  249
# initial  value 169959845813848.718750
# final  value 169958868783208.187500
# converged
# # weights:  280
# initial  value 169960704405710.218750
# final  value 169958868793852.375000
# converged
# # weights:  311
# initial  value 169959429321710.437500
# final  value 169958868789848.531250
# converged
# # weights:  32
# initial  value 169960158141308.500000
# final  value 169958869157315.906250
# converged
# # weights:  63
# initial  value 169960341683251.968750
# final  value 169958869433856.718750
# converged
# # weights:  94
# initial  value 169961148449887.437500
# final  value 169958869622743.843750
# converged
# # weights:  125
# initial  value 169960581680673.593750
# final  value 169958868802274.437500
# converged
# # weights:  156
# initial  value 169960636788407.406250
# final  value 169958868802903.406250
# converged
# # weights:  187
# initial  value 169960611788686.687500
# final  value 169958868817023.000000
# converged
# # weights:  218
# initial  value 169960252551396.093750
# final  value 169958868829682.156250
# converged
# # weights:  249
# initial  value 169961689155439.250000
# final  value 169958869582113.531250
# converged
# # weights:  280
# initial  value 169959581025693.218750
# final  value 169958868823704.218750
# converged
# # weights:  311
# initial  value 169959319580440.500000
# final  value 169958868794061.718750
# converged
# # weights:  32
# initial  value 169960220697685.718750
# final  value 169958869446141.437500
# converged
# # weights:  63
# initial  value 169960899762594.718750
# final  value 169958870162303.375000
# converged
# # weights:  94
# initial  value 169961164245859.750000
# final  value 169958869565760.156250
# converged
# # weights:  125
# initial  value 169960402282624.125000
# final  value 169958868846136.906250
# converged
# # weights:  156
# initial  value 169960790885294.625000
# final  value 169958868845039.875000
# converged
# # weights:  187
# initial  value 169960310583076.218750
# final  value 169958868887650.500000
# converged
# # weights:  218
# initial  value 169959703603356.531250
# final  value 169958868825875.562500
# converged
# # weights:  249
# initial  value 169961563309256.875000
# final  value 169958870424750.718750
# converged
# # weights:  280
# initial  value 169960418288247.187500
# final  value 169958868934054.906250
# converged
# # weights:  311
# initial  value 169960098055516.000000
# final  value 169958868772601.437500
# converged
# # weights:  32
# initial  value 169960858180897.187500
# final  value 169958869875555.406250
# converged
# # weights:  63
# initial  value 169961224691605.968750
# final  value 169958869619709.500000
# converged
# # weights:  94
# initial  value 169960408965833.156250
# final  value 169958868918502.000000
# converged
# # weights:  125
# initial  value 169960491609940.937500
# final  value 169958870633935.375000
# converged
# # weights:  156
# initial  value 169960445904192.531250
# final  value 169958868959477.781250
# converged
# # weights:  187
# initial  value 169960074080120.093750
# final  value 169958868903648.000000
# converged
# # weights:  218
# initial  value 169960817729089.906250
# final  value 169958868775905.750000
# converged
# # weights:  249
# initial  value 169959470966438.781250
# final  value 169958868804248.437500
# converged
# # weights:  280
# initial  value 169960345550225.250000
# final  value 169958868956882.937500
# converged
# # weights:  311
# initial  value 169959209532412.125000
# final  value 169958868798153.000000
# converged
# # weights:  32
# initial  value 168566282702747.312500
# final  value 168564989710988.750000
# converged
# # weights:  63
# initial  value 168567260869391.187500
# final  value 168564989723467.875000
# converged
# # weights:  94
# initial  value 168566727249334.500000
# final  value 168564989722798.375000
# converged
# # weights:  125
# initial  value 168565869624358.250000
# final  value 168564989710828.875000
# converged
# # weights:  156
# initial  value 168566322421057.937500
# final  value 168564989711765.875000
# converged
# # weights:  187
# initial  value 168566782378965.562500
# final  value 168564989712189.593750
# converged
# # weights:  218
# initial  value 168566727927569.781250
# final  value 168564989711667.093750
# converged
# # weights:  249
# initial  value 168566006858993.093750
# final  value 168564989710348.281250
# converged
# # weights:  280
# initial  value 168566144007922.968750
# final  value 168564989711539.781250
# converged
# # weights:  311
# initial  value 168566058293053.843750
# final  value 168564989711833.781250
# converged
# # weights:  32
# initial  value 168566384154420.656250
# final  value 168564989739175.187500
# converged
# # weights:  63
# initial  value 168566213689106.718750
# final  value 168564989727415.125000
# converged
# # weights:  94
# initial  value 168565700096661.375000
# final  value 168564989711179.031250
# converged
# # weights:  125
# initial  value 168565515868031.562500
# final  value 168564989711133.312500
# converged
# # weights:  156
# initial  value 168567175132105.937500
# final  value 168564989713137.937500
# converged
# # weights:  187
# initial  value 168566935940467.968750
# final  value 168564989712603.031250
# converged
# # weights:  218
# initial  value 168565822690989.750000
# final  value 168564989712509.843750
# converged
# # weights:  249
# initial  value 168567892044357.125000
# final  value 168564989734249.250000
# converged
# # weights:  280
# initial  value 168565726131850.437500
# final  value 168564989711865.281250
# converged
# # weights:  311
# initial  value 168565955315922.656250
# final  value 168564989712124.468750
# converged
# # weights:  32
# initial  value 168567110921051.125000
# final  value 168564989785714.281250
# converged
# # weights:  63
# initial  value 168566482616983.281250
# final  value 168564989712856.093750
# converged
# # weights:  94
# initial  value 168566001599085.875000
# final  value 168564989712564.250000
# converged
# # weights:  125
# initial  value 168566649918179.437500
# final  value 168564989765239.375000
# converged
# # weights:  156
# initial  value 168566503485955.375000
# final  value 168564989713991.750000
# converged
# # weights:  187
# initial  value 168567468159105.562500
# final  value 168564989773774.843750
# converged
# # weights:  218
# initial  value 168566270896185.312500
# final  value 168564989713042.093750
# converged
# # weights:  249
# initial  value 168567132461406.187500
# final  value 168564989715965.250000
# converged
# # weights:  280
# initial  value 168567320903675.187500
# final  value 168564989715503.562500
# converged
# # weights:  311
# initial  value 168566133984565.593750
# final  value 168564989716558.593750
# converged
# # weights:  32
# initial  value 168566341287850.562500
# final  value 168564989713815.062500
# converged
# # weights:  63
# initial  value 168567034406091.968750
# final  value 168564989806128.500000
# converged
# # weights:  94
# initial  value 168567445259062.656250
# final  value 168564989823008.781250
# converged
# # weights:  125
# initial  value 168567536549910.218750
# final  value 168564989765386.187500
# converged
# # weights:  156
# initial  value 168566979151254.187500
# final  value 168564989716685.875000
# converged
# # weights:  187
# initial  value 168565570420723.343750
# final  value 168564989712388.718750
# converged
# # weights:  218
# initial  value 168566845011580.312500
# final  value 168564989718163.843750
# converged
# # weights:  249
# initial  value 168567027680040.156250
# final  value 168564989724671.093750
# converged
# # weights:  280
# initial  value 168567557081483.781250
# final  value 168564989719091.687500
# converged
# # weights:  311
# initial  value 168567247637286.250000
# final  value 168564989721421.250000
# converged
# # weights:  32
# initial  value 168566265612483.593750
# final  value 168564989715916.468750
# converged
# # weights:  63
# initial  value 168566661550761.000000
# final  value 168564989710378.968750
# converged
# # weights:  94
# initial  value 168566068432313.500000
# final  value 168564989718832.906250
# converged
# # weights:  125
# initial  value 168566546858094.843750
# final  value 168564989719527.531250
# converged
# # weights:  156
# initial  value 168567097304610.125000
# final  value 168564989855946.500000
# converged
# # weights:  187
# initial  value 168566402740927.062500
# final  value 168564989722958.281250
# converged
# # weights:  218
# initial  value 168566239751534.093750
# final  value 168564989721013.781250
# converged
# # weights:  249
# initial  value 168566237229355.781250
# final  value 168564989721307.250000
# converged
# # weights:  280
# initial  value 168566691665301.625000
# final  value 168564989722154.187500
# converged
# # weights:  311
# initial  value 168567788459095.687500
# final  value 168564989721557.312500
# converged
# # weights:  32
# initial  value 168566437043275.218750
# final  value 168564989725801.656250
# converged
# # weights:  63
# initial  value 168566416124372.593750
# final  value 168564989859997.593750
# converged
# # weights:  94
# initial  value 168566123489158.218750
# final  value 168564989720837.937500
# converged
# # weights:  125
# initial  value 168566731783826.437500
# final  value 168564989724469.000000
# converged
# # weights:  156
# initial  value 168567320977825.687500
# final  value 168564990003732.375000
# converged
# # weights:  187
# initial  value 168567604964885.625000
# final  value 168564989732200.343750
# converged
# # weights:  218
# initial  value 168566887143771.218750
# final  value 168564989725868.812500
# converged
# # weights:  249
# initial  value 168566468703827.781250
# final  value 168564989741136.406250
# converged
# # weights:  280
# initial  value 168566641757171.968750
# final  value 168564989721854.812500
# converged
# # weights:  311
# initial  value 168566931292187.468750
# final  value 168564989713727.593750
# converged
# # weights:  32
# initial  value 168567179625029.562500
# final  value 168564989933256.750000
# converged
# # weights:  63
# initial  value 168566326642381.875000
# final  value 168564989774999.000000
# converged
# # weights:  94
# initial  value 168566466033767.906250
# final  value 168564989733793.218750
# converged
# # weights:  125
# initial  value 168566380635366.093750
# final  value 168564989736048.937500
# converged
# # weights:  156
# initial  value 168567234923794.812500
# final  value 168564989719958.562500
# converged
# # weights:  187
# initial  value 168565732627160.781250
# final  value 168564989728055.968750
# converged
# # weights:  218
# initial  value 168567104530282.656250
# final  value 168564989737184.625000
# converged
# # weights:  249
# initial  value 168566986684533.875000
# final  value 168564989744162.968750
# converged
# # weights:  280
# initial  value 168566286188657.843750
# final  value 168564989749633.875000
# converged
# # weights:  311
# initial  value 168566810224174.468750
# final  value 168564989723774.250000
# converged
# # weights:  32
# initial  value 168566740831100.031250
# final  value 168564989744245.312500
# converged
# # weights:  63
# initial  value 168566262783978.812500
# final  value 168564989745315.250000
# converged
# # weights:  94
# initial  value 168566186892090.531250
# final  value 168564989745954.218750
# converged
# # weights:  125
# initial  value 168566874125131.718750
# final  value 168564989753751.468750
# converged
# # weights:  156
# initial  value 168567257904515.812500
# final  value 168564989756361.875000
# converged
# # weights:  187
# initial  value 168567049761500.718750
# final  value 168564989776076.531250
# converged
# # weights:  218
# initial  value 168567391735436.125000
# final  value 168564989759309.156250
# converged
# # weights:  249
# initial  value 168567393775327.062500
# final  value 168564989755623.968750
# converged
# # weights:  280
# initial  value 168567094356847.500000
# final  value 168564989808846.156250
# converged
# # weights:  311
# initial  value 168566433058086.187500
# final  value 168564989799639.562500
# converged
# # weights:  32
# initial  value 168567194034958.562500
# final  value 168564990421908.875000
# converged
# # weights:  63
# initial  value 168566380258821.656250
# final  value 168564989757374.468750
# converged
# # weights:  94
# initial  value 168567055080455.656250
# final  value 168564990779365.062500
# converged
# # weights:  125
# initial  value 168566769051021.718750
# final  value 168564989785788.375000
# converged
# # weights:  156
# initial  value 168566240747654.750000
# final  value 168564989800969.500000
# converged
# # weights:  187
# initial  value 168566910274976.093750
# final  value 168564989839017.593750
# converged
# # weights:  218
# initial  value 168567589315556.781250
# final  value 168564990939381.281250
# converged
# # weights:  249
# initial  value 168567290246321.812500
# final  value 168564989792133.156250
# converged
# # weights:  280
# initial  value 168566504339590.500000
# final  value 168564989814035.812500
# converged
# # weights:  311
# initial  value 168566303770151.343750
# final  value 168564989894725.468750
# converged
# # weights:  32
# initial  value 168566428891612.406250
# final  value 168564989796041.875000
# converged
# # weights:  63
# initial  value 168567006046412.625000
# final  value 168564991244004.062500
# converged
# # weights:  94
# initial  value 168566597588441.125000
# final  value 168564989808272.093750
# converged
# # weights:  125
# initial  value 168566696305277.437500
# final  value 168564989878316.125000
# converged
# # weights:  156
# initial  value 168566512828143.218750
# final  value 168564989790249.000000
# converged
# # weights:  187
# initial  value 168566698240836.656250
# final  value 168564989856686.312500
# converged
# # weights:  218
# initial  value 168566200705532.218750
# final  value 168564989810379.125000
# converged
# # weights:  249
# initial  value 168567185855007.750000
# final  value 168564989931854.781250
# converged
# # weights:  280
# initial  value 168567025593627.812500
# final  value 168564989899182.656250
# converged
# # weights:  311
# initial  value 168567113406033.687500
# final  value 168564989876451.906250
# converged
# # weights:  32
# initial  value 170067738767250.562500
# final  value 170065831715442.125000
# converged
# # weights:  63
# initial  value 170067797884739.031250
# final  value 170065831718139.656250
# converged
# # weights:  94
# initial  value 170067416932269.250000
# final  value 170065831696150.187500
# converged
# # weights:  125
# initial  value 170067242385415.687500
# final  value 170065831711761.906250
# converged
# # weights:  156
# initial  value 170067904572810.500000
# final  value 170065831696045.718750
# converged
# # weights:  187
# initial  value 170067687813824.031250
# final  value 170065831696244.218750
# converged
# # weights:  218
# initial  value 170067969383013.531250
# final  value 170065831696399.406250
# converged
# # weights:  249
# initial  value 170067964847296.812500
# final  value 170065831697890.031250
# converged
# # weights:  280
# initial  value 170068250114660.531250
# final  value 170065831696422.687500
# converged
# # weights:  311
# initial  value 170067571798638.531250
# final  value 170065831696927.531250
# converged
# # weights:  32
# initial  value 170067194724318.781250
# final  value 170065831696063.156250
# converged
# # weights:  63
# initial  value 170067653792477.500000
# final  value 170065831696493.500000
# converged
# # weights:  94
# initial  value 170067078432991.125000
# final  value 170065831696239.406250
# converged
# # weights:  125
# initial  value 170067234683491.156250
# final  value 170065831697232.437500
# converged
# # weights:  156
# initial  value 170067977582868.218750
# final  value 170065831716347.250000
# converged
# # weights:  187
# initial  value 170067779063744.968750
# final  value 170065831698601.875000
# converged
# # weights:  218
# initial  value 170067383869408.437500
# final  value 170065831694941.593750
# converged
# # weights:  249
# initial  value 170067396197355.500000
# final  value 170065831696206.875000
# converged
# # weights:  280
# initial  value 170068066880788.437500
# final  value 170065831698583.375000
# converged
# # weights:  311
# initial  value 170067548099932.093750
# final  value 170065831701156.531250
# converged
# # weights:  32
# initial  value 170067271293622.531250
# final  value 170065831726882.437500
# converged
# # weights:  63
# initial  value 170067755118991.312500
# final  value 170065831697812.937500
# converged
# # weights:  94
# initial  value 170067921474674.750000
# final  value 170065831758344.062500
# converged
# # weights:  125
# initial  value 170066980566247.375000
# final  value 170065831696801.468750
# converged
# # weights:  156
# initial  value 170067461410546.656250
# final  value 170065831699056.968750
# converged
# # weights:  187
# initial  value 170067711217228.937500
# final  value 170065831699451.312500
# converged
# # weights:  218
# initial  value 170068078472978.656250
# final  value 170065831769532.906250
# converged
# # weights:  249
# initial  value 170068072399187.187500
# final  value 170065831764504.562500
# converged
# # weights:  280
# initial  value 170068320355035.250000
# final  value 170065831782949.218750
# converged
# # weights:  311
# initial  value 170067774871868.687500
# final  value 170065831700129.156250
# converged
# # weights:  32
# initial  value 170067927943975.031250
# final  value 170065831777239.843750
# converged
# # weights:  63
# initial  value 170067118096703.875000
# final  value 170065831763000.687500
# converged
# # weights:  94
# initial  value 170067511518846.375000
# final  value 170065831698943.500000
# converged
# # weights:  125
# initial  value 170067410449439.906250
# final  value 170065831701105.468750
# converged
# # weights:  156
# initial  value 170067511074329.500000
# final  value 170065831702436.156250
# converged
# # weights:  187
# initial  value 170067516646551.906250
# final  value 170065831704058.000000
# converged
# # weights:  218
# initial  value 170066906380887.781250
# final  value 170065831701764.937500
# converged
# # weights:  249
# initial  value 170067235531837.437500
# final  value 170065831703811.531250
# converged
# # weights:  280
# initial  value 170068692225813.687500
# final  value 170065831758122.281250
# converged
# # weights:  311
# initial  value 170068101242547.156250
# final  value 170065831701126.906250
# converged
# # weights:  32
# initial  value 170068076256931.218750
# final  value 170065831770462.968750
# converged
# # weights:  63
# initial  value 170067767748462.812500
# final  value 170065831788807.343750
# converged
# # weights:  94
# initial  value 170068028704623.562500
# final  value 170065831872007.187500
# converged
# # weights:  125
# initial  value 170066993805921.968750
# final  value 170065831801231.968750
# converged
# # weights:  156
# initial  value 170067141408483.718750
# final  value 170065831705138.062500
# converged
# # weights:  187
# initial  value 170067670475836.281250
# final  value 170065831705066.531250
# converged
# # weights:  218
# initial  value 170066807426380.156250
# final  value 170065831706454.968750
# converged
# # weights:  249
# initial  value 170066774923107.250000
# final  value 170065831700980.125000
# converged
# # weights:  280
# initial  value 170066591156807.812500
# final  value 170065831704533.312500
# converged
# # weights:  311
# initial  value 170068373726474.906250
# final  value 170065831706032.218750
# converged
# # weights:  32
# initial  value 170067413085239.281250
# final  value 170065831860460.437500
# converged
# # weights:  63
# initial  value 170067760197462.812500
# final  value 170065831710747.781250
# converged
# # weights:  94
# initial  value 170066944112405.468750
# final  value 170065831831035.406250
# converged
# # weights:  125
# initial  value 170066315976236.406250
# final  value 170065831698511.406250
# converged
# # weights:  156
# initial  value 170068369780004.156250
# final  value 170065832032658.250000
# converged
# # weights:  187
# initial  value 170066902506188.656250
# final  value 170065831705666.000000
# converged
# # weights:  218
# initial  value 170066598931196.093750
# final  value 170065831704107.843750
# converged
# # weights:  249
# initial  value 170067008544640.031250
# final  value 170065831710969.343750
# converged
# # weights:  280
# initial  value 170066928651045.468750
# final  value 170065831694927.625000
# converged
# # weights:  311
# initial  value 170067859196294.312500
# final  value 170065831705613.375000
# converged
# # weights:  32
# initial  value 170066907808876.468750
# final  value 170065831710076.062500
# converged
# # weights:  63
# initial  value 170067901287639.531250
# final  value 170065832137830.593750
# converged
# # weights:  94
# initial  value 170067465501927.062500
# final  value 170065832136308.968750
# converged
# # weights:  125
# initial  value 170066880615076.593750
# final  value 170065831710999.000000
# converged
# # weights:  156
# initial  value 170067055421581.312500
# final  value 170065831721171.812500
# converged
# # weights:  187
# initial  value 170067810276245.156250
# final  value 170065831696443.500000
# converged
# # weights:  218
# initial  value 170066469625842.750000
# final  value 170065831704476.531250
# converged
# # weights:  249
# initial  value 170067563879587.062500
# final  value 170065831741439.156250
# converged
# # weights:  280
# initial  value 170068143390184.593750
# final  value 170065831739458.156250
# converged
# # weights:  311

# %%
??mlpWeightDecay
# Out:
# No vignettes or demos or help files found with alias or concept or
# title matching 'mlpWeightDecay' using fuzzy matching.

# %% [markdown]
# # Just the MLP prediction

# %%
mlp_simulation <- function(data, nrun = 10, k_fold = 10, steps = 10){
  # Create empty list to store evaluation dataframes
  eval_list <- list()
  
  # Set initial seed
  s <- 1234
  
  for (i in 1:nrun){
    set.seed(s + i)
    
    # Define trainControl with k-fold cross-validation
    train_control <- trainControl(method = "cv", number = k_fold)
    
    # Define the grid for hyperparameter tuning
    size_values <- seq(1, 10, length.out = steps)
    decay_values <- 10^seq(log10(0.0001), log10(0.01), length.out = steps)
    
    # Create grid
    grid <- expand.grid(size = size_values, decay = decay_values)
    
    # Train the MLP model using caret with grid search
    mlp_model <- train(income ~ ., data = data, method = "nnet",
                       tuneGrid = grid, trControl = train_control, linout = TRUE, trace = FALSE)
    
    # Evaluation metrics
    predictions <- predict(mlp_model, newdata = data)
    
    if (is.numeric(data$income)) {
      eval <- as.data.frame(evaluation_metrics_cont(predictions, data$income))
    } else if (is.factor(data$income)) {
      eval <- as.data.frame(evaluation_metrics_factor(predictions, data$income))
    } else {
      stop("The predicted target has to be numeric or factor.")
    }
    
    eval_list[[i]] <- eval
    print(paste("run", i, "completed"))
  }
  
  # Average over all runs
  sum_df <- Reduce(function(x, y) Map(`+`, x, y), eval_list)
  eval_avg <- lapply(sum_df, function(col) col / length(eval_list))
  
  # Convert the list back to a dataframe
  # Store row names
  rownames <- row.names(eval_list[[1]])
  
  # Convert the list back to a dataframe
  eval_avg <- as.data.frame(eval_avg)
  
  # Set back the row names
  row.names(eval_avg) <- rownames
  
  # Returns
  results <- list(eval_avg = eval_avg)
  return(results)
}

# Example function for continuous evaluation metrics
evaluation_metrics_cont <- function(predictions, actuals) {
  mse <- mean((predictions - actuals)^2)
  rmse <- sqrt(mse)
  mae <- mean(abs(predictions - actuals))
  return(data.frame(MSE = mse, RMSE = rmse, MAE = mae))
}

# Example function for factor evaluation metrics
evaluation_metrics_factor <- function(predictions, actuals) {
  confusion <- confusionMatrix(predictions, actuals)
  accuracy <- confusion$overall['Accuracy']
  return(data.frame(Accuracy = accuracy))
}

# %%
cps_res <- mlp_simulation(cpspop)

# %%
adult_res <- mlp_simulation(adult)

# %% [markdown]
# ### Save the results

# %%
# Bind results
mlp_pred_results <- list(cps_res = cps_res, adult_res = adult_res)
# File pth for output
file <- "/user/emma.foessing01/u11969/results/mlp_pred_results.RData" 
dir.create(dirname(output_file), recursive = TRUE, showWarnings = FALSE) # create dir if not there
# Save the results to an RData file 
save(results, file = output_file)

# %% [markdown]
# # MLP prediction function

# %% [markdown]
# ### Packages

# %%
list_of_packages <- c ("synthpop", "insight", "party", "dplyr", "rpart", "rpart.plot", "randomForest", "pROC", "caret", "pracma", "here", "Hmisc", "randomForest",  "xgboost", "data.table", "RSNNS", "nnet")

# Function to check and install packages
install_if_missing <- function(p) {
  if (!requireNamespace(p, quietly = TRUE)) {
    install.packages(p, dependencies = TRUE)
  }
  library(p, character.only = TRUE)
}

# Install and load all required packages
lapply(list_of_packages, install_if_missing)
# Out:
# Find out more at https://www.synthpop.org.uk/
#
# Lade n"otiges Paket: grid
#
# Lade n"otiges Paket: mvtnorm
#
# Lade n"otiges Paket: modeltools
#
# Lade n"otiges Paket: stats4
#
# Lade n"otiges Paket: strucchange
#
# Lade n"otiges Paket: zoo
#
#
# Attache Paket: 'zoo'
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     as.Date, as.Date.numeric
#
#
# Lade n"otiges Paket: sandwich
#
#
# Attache Paket: 'dplyr'
#
#
# Das folgende Objekt ist maskiert 'package:party':
#
#     where
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     filter, lag
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attache Paket: 'randomForest'
#
#
# Das folgende Objekt ist maskiert 'package:dplyr':
#
#     combine
#
#
# Type 'citation("pROC")' for a citation.
#
#
# Attache Paket: 'pROC'
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     cov, smooth, var
#
#
# Lade n"otiges Paket: ggplot2
#
#
# Attache Paket: 'ggplot2'
#
#
# Das folgende Objekt ist maskiert 'package:randomForest':
#
#     margin
#
#
# Lade n"otiges Paket: lattice
#
# here() starts at /Users/emmafoessing/Documents/Master/MA/Code/Master-Thesis
#
#
# Attache Paket: 'Hmisc'
#
#
# Das folgende Objekt ist maskiert 'package:pracma':
#
#     ceil
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     src, summarize
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     format.pval, units
#
#
#
# Attache Paket: 'xgboost'
#
#
# Das folgende Objekt ist maskiert 'package:dplyr':
#
#     slice
#
#
#
# Attache Paket: 'data.table'
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     between, first, last
#
#
# Die folgenden Objekte sind maskiert von 'package:zoo':
#
#     yearmon, yearqtr
#
#
# Lade n"otiges Paket: Rcpp
#
#
# Attache Paket: 'RSNNS'
#
#
# Die folgenden Objekte sind maskiert von 'package:caret':
#
#     confusionMatrix, train
# [[1]]
# [1] "synthpop"  "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
# [1] "insight"   "synthpop"  "stats"     "graphics"  "grDevices" "utils"
# [7] "datasets"  "methods"   "base"
#
# [[3]]
#  [1] "party"       "strucchange" "sandwich"    "zoo"         "modeltools"
#  [6] "stats4"      "mvtnorm"     "grid"        "insight"     "synthpop"
# [11] "stats"       "graphics"    "grDevices"   "utils"       "datasets"
# [16] "methods"     "base"
#
# [[4]]
#  [1] "dplyr"       "party"       "strucchange" "sandwich"    "zoo"
#  [6] "modeltools"  "stats4"      "mvtnorm"     "grid"        "insight"
# [11] "synthpop"    "stats"       "graphics"    "grDevices"   "utils"
# [16] "datasets"    "methods"     "base"
#
# [[5]]
#  [1] "rpart"       "dplyr"       "party"       "strucchange" "sandwich"
#  [6] "zoo"         "modeltools"  "stats4"      "mvtnorm"     "grid"
# [11] "insight"     "synthpop"    "stats"       "graphics"    "grDevices"
# [16] "utils"       "datasets"    "methods"     "base"
#
# [[6]]
#  [1] "rpart.plot"  "rpart"       "dplyr"       "party"       "strucchange"
#  [6] "sandwich"    "zoo"         "modeltools"  "stats4"      "mvtnorm"
# [11] "grid"        "insight"     "synthpop"    "stats"       "graphics"
# [16] "grDevices"   "utils"       "datasets"    "methods"     "base"
#
# [[7]]
#  [1] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
#  [6] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [11] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [16] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [21] "base"
#
# [[8]]
#  [1] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
#  [6] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [11] "stats4"       "mvtnorm"      "grid"         "insight"      "synthpop"
# [16] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [21] "methods"      "base"
#
# [[9]]
#  [1] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
#  [6] "rpart.plot"   "rpart"        "dplyr"        "party"        "strucchange"
# [11] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [16] "grid"         "insight"      "synthpop"     "stats"        "graphics"
# [21] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[10]]
#  [1] "pracma"       "caret"        "lattice"      "ggplot2"      "pROC"
#  [6] "randomForest" "rpart.plot"   "rpart"        "dplyr"        "party"
# [11] "strucchange"  "sandwich"     "zoo"          "modeltools"   "stats4"
# [16] "mvtnorm"      "grid"         "insight"      "synthpop"     "stats"
# [21] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [26] "base"
#
# [[11]]
#  [1] "here"         "pracma"       "caret"        "lattice"      "ggplot2"
#  [6] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
# [11] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [16] "stats4"       "mvtnorm"      "grid"         "insight"      "synthpop"
# [21] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [26] "methods"      "base"
#
# [[12]]
#  [1] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
#  [6] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [11] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [16] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [21] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [26] "datasets"     "methods"      "base"
#
# [[13]]
#  [1] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
#  [6] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [11] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [16] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [21] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [26] "datasets"     "methods"      "base"
#
# [[14]]
#  [1] "xgboost"      "Hmisc"        "here"         "pracma"       "caret"
#  [6] "lattice"      "ggplot2"      "pROC"         "randomForest" "rpart.plot"
# [11] "rpart"        "dplyr"        "party"        "strucchange"  "sandwich"
# [16] "zoo"          "modeltools"   "stats4"       "mvtnorm"      "grid"
# [21] "insight"      "synthpop"     "stats"        "graphics"     "grDevices"
# [26] "utils"        "datasets"     "methods"      "base"
#
# [[15]]
#  [1] "data.table"   "xgboost"      "Hmisc"        "here"         "pracma"
#  [6] "caret"        "lattice"      "ggplot2"      "pROC"         "randomForest"
# [11] "rpart.plot"   "rpart"        "dplyr"        "party"        "strucchange"
# [16] "sandwich"     "zoo"          "modeltools"   "stats4"       "mvtnorm"
# [21] "grid"         "insight"      "synthpop"     "stats"        "graphics"
# [26] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[16]]
#  [1] "RSNNS"        "Rcpp"         "data.table"   "xgboost"      "Hmisc"
#  [6] "here"         "pracma"       "caret"        "lattice"      "ggplot2"
# [11] "pROC"         "randomForest" "rpart.plot"   "rpart"        "dplyr"
# [16] "party"        "strucchange"  "sandwich"     "zoo"          "modeltools"
# [21] "stats4"       "mvtnorm"      "grid"         "insight"      "synthpop"
# [26] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [31] "methods"      "base"
#
# [[17]]
#  [1] "nnet"         "RSNNS"        "Rcpp"         "data.table"   "xgboost"
#  [6] "Hmisc"        "here"         "pracma"       "caret"        "lattice"
# [11] "ggplot2"      "pROC"         "randomForest" "rpart.plot"   "rpart"
# [16] "dplyr"        "party"        "strucchange"  "sandwich"     "zoo"
# [21] "modeltools"   "stats4"       "mvtnorm"      "grid"         "insight"
# [26] "synthpop"     "stats"        "graphics"     "grDevices"    "utils"
# [31] "datasets"     "methods"      "base"

# %% [markdown]
# ### Data

# %%
load(file = (paste0(here(), "/cpspop.RData")))
adult <- read.csv(file = (paste0(here(),"/adult_preprocessed.csv")))
# delete NAs
adult[adult == "?"] <- NA
adult <- na.omit(adult)

adult$workclass <- as.factor(adult$workclass)
adult$education <- as.factor(adult$education)
adult$marital_status <- as.factor(adult$marital_status)
adult$relationship <- as.factor(adult$relationship)
adult$race <- as.factor(adult$race)
adult$sex <- as.factor(adult$sex)
adult$native_country <- as.factor(adult$native_country)
adult$income <- as.factor(adult$income)
adult$occupation <- as.factor(adult$occupation)

# %% [markdown]
# ### Helper functions

# %%
## eval cont targets
evaluation_metrics_cont <- function(predictions, test_set){
  MAE <- mean(abs(predictions - test_set$income))
  MSE <- mean((predictions - test_set$income)^2)
  RMSE <- sqrt(MSE)

  SS_res <- sum((test_set$income - predictions)^2)
  SS_tot <- sum((test_set$income - mean(test_set$income))^2)
  R_squared <- 1 - (SS_res / SS_tot)

  MAPE <- mean(abs((test_set$income - predictions) / test_set$income)) * 100

  # Create the dataframe
  metrics_df <- data.frame(
        MAE = MAE, 
        MSE = MSE, 
        RMSE = RMSE,
        R_squared = R_squared, 
        MAPE = MAPE)

  return(metrics_df)
}

# %%
## eval factored targets
evaluation_metrics_factor <- function(predictions, test_set){
    # confusion matrix for the prediction on original data
    cm <- confusionMatrix(predictions, test_set$income,
                mode = "everything")

    # saving evaluation metrics
    accuracy <- cm$overall['Accuracy']
    f1 <- cm$byClass['F1']
    sens <- cm$byClass['Sensitivity']
    spec <- cm$byClass['Specificity']

    # Create the dataframe
    metrics_df <- data.frame(
        Accuracy = accuracy, 
        F1 = f1, 
        Sensitivity = sens, 
        Specificity = spec
    )
    
    return(metrics_df)
}

# %%
mlp_pred <- function(data, outer_folds, size_steps, decay_steps, inner_folds){
    # adjust evaluation metric to fit both numeric and factored targets
    summaryFunctionType <- if (is.numeric(data$income)) defaultSummary else multiClassSummary
    # metric: train() uses per default RSME and Accuracy for numeric and factored targets

    #  set control args
    outer_control <- trainControl(method = "cv", number = outer_folds,
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)
        
    inner_control <- trainControl(method = "cv", number = inner_folds, 
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)

    # Define the grid for hyperparameter tuning
    size_values <- seq(1, 10, length.out = size_steps)
    decay_values <- 10^seq(log10(0.0001), log10(0.01), length.out = decay_steps)

    # Create grid
    tunegrid <- expand.grid(size = size_values, decay = decay_values)

    # Initialize variables to store results
    outer_results <- list()

    outer_cv_folds = createFolds(data$income, k = outer_folds)
    
    # Outer loop: Cross-validation for model evaluation
    for (i in seq_along(outer_folds)) {
        
        # Split data into outer folds
        outer_test_index = outer_cv_folds[[i]]
        outer_testData = data[outer_test_index,]
        outer_trainData  = data[-outer_test_index,]
        
        # Hyperparameter tuning using inner CV
        # No need for inner loop because "train" does k-fold CV already
        mlp_model <- caret::train(income ~ ., 
                           data = outer_trainData, 
                           method = "nnet", 
                           tuneGrid = tunegrid, 
                           trControl = inner_control)#,
                           #metric = metricType)
            

        # Store the best hyperparameters
        best_hyperparameters <- mlp_model$bestTune
        print("best HP")
        print(mlp_model$bestTune)

        # Train the final model on the outer training set with the best hyperparameters
        final_model <- caret::train(income ~ ., 
                             data = outer_trainData, 
                             method = "nnet", 
                             trControl = outer_control, 
                             tuneGrid = best_hyperparameters)

        # Testing the final model on the outer test set
        predictions <- predict(final_model, newdata = outer_testData)
        
        if (is.numeric(data$income)) {
            eval <- evaluation_metrics_cont(predictions, outer_testData)
        } else if (is.factor(data$income)) {
            eval <- evaluation_metrics_factor(predictions, outer_testData)
        } else {
            stop("The predicted target has to be numeric or factor.")
        }

        # Store the evaluation metrics for this outer fold
        outer_results[[i]] <- eval
    }

    # Average the evaluation metrics over the outer folds
    eval_avg_outer_folds <- do.call(rbind, outer_results) %>%
                            summarise(across(everything(), mean, na.rm = TRUE))

    

    # Return the average evaluation metrics
    return(eval_avg_outer_folds)
}

# %%
res <- mlp_pred(data = adult, outer_folds = 5, size_steps = 10, decay_steps = 10, inner_folds = 5)
# Out:
# # weights:  86
# initial  value 17835.609847
# final  value 10832.187275
# converged
# # weights:  171
# initial  value 13579.916589
# iter  10 value 10694.931363
# final  value 10694.873243
# converged
# # weights:  256
# initial  value 18828.392069
# final  value 10832.189731
# converged
# # weights:  341
# initial  value 18384.463150
# iter  10 value 10715.580988
# final  value 10705.936230
# converged
# # weights:  426
# initial  value 12180.498043
# iter  10 value 10697.106099
# final  value 10696.143318
# converged
# # weights:  511
# initial  value 12088.117689
# iter  10 value 10773.765994
# final  value 10773.747399
# converged
# # weights:  596
# initial  value 10842.529966
# iter  10 value 10737.825367
# final  value 10737.438562
# converged
# # weights:  681
# initial  value 10659.195273
# iter  10 value 10250.187379
# iter  20 value 9679.335737
# iter  30 value 9014.297759
# iter  40 value 8843.625060
# iter  50 value 8357.883816
# iter  60 value 8196.014430
# iter  70 value 8174.713983
# iter  80 value 8165.255274
# iter  90 value 8151.700281
# iter 100 value 8149.634833
# final  value 8149.634833
# stopped after 100 iterations
# # weights:  766
# initial  value 10850.929963
# final  value 10818.297089
# converged
# # weights:  851
# initial  value 39393.192215
# iter  10 value 10609.282980
# final  value 10609.254770
# converged
# # weights:  86
# initial  value 17853.004098
# final  value 10832.188414
# converged
# # weights:  171
# initial  value 11597.662951
# iter  10 value 10402.670304
# final  value 10402.669901
# converged
# # weights:  256
# initial  value 11190.064136
# final  value 10765.635311
# converged
# # weights:  341
# initial  value 14640.695287
# iter  10 value 10722.439815
# final  value 10719.905826
# converged
# # weights:  426
# initial  value 11301.272794
# final  value 10780.686071
# converged
# # weights:  511
# initial  value 10855.525675
# iter  10 value 10770.507061
# iter  10 value 10770.507037
# iter  10 value 10770.507037
# final  value 10770.507037
# converged
# # weights:  596
# initial  value 12985.877796
# final  value 10789.070783
# converged
# # weights:  681
# initial  value 13557.213862
# iter  10 value 10698.172866
# iter  20 value 10694.177536
# final  value 10694.169650
# converged
# # weights:  766
# initial  value 11070.661953
# final  value 10800.215243
# converged
# # weights:  851
# initial  value 11771.733112
# iter  10 value 10693.281381
# final  value 10693.263348
# converged
# # weights:  86
# initial  value 16934.268300
# final  value 10832.189494
# converged
# # weights:  171
# initial  value 17288.917067
# iter  10 value 10898.406357
# iter  20 value 10719.413392
# final  value 10718.502843
# converged
# # weights:  256
# initial  value 12004.334835
# final  value 10832.197072
# converged
# # weights:  341
# initial  value 11010.537296
# iter  10 value 10116.930485
# iter  20 value 10107.936015
# final  value 10107.933681
# converged
# # weights:  426
# initial  value 11545.383550
# final  value 10775.382585
# converged
# # weights:  511
# initial  value 22313.404854
# iter  10 value 10649.030225
# final  value 10649.027847
# converged
# # weights:  596
# initial  value 14862.146696
# iter  10 value 10822.917030
# iter  20 value 10822.646037
# final  value 10822.605369
# converged
# # weights:  681
# initial  value 11181.277760
# iter  10 value 10269.502039
# iter  20 value 9902.579309
# iter  30 value 9902.518721
# iter  40 value 9900.756665
# iter  50 value 9882.617315
# iter  60 value 9881.570035
# iter  70 value 9863.577991
# iter  80 value 9863.086861
# iter  90 value 9862.795421
# iter 100 value 9844.347454
# final  value 9844.347454
# stopped after 100 iterations
# # weights:  766
# initial  value 16321.114446
# iter  10 value 10611.863328
# iter  20 value 10578.524664
# iter  30 value 10058.029469
# iter  40 value 10011.443774
# final  value 10011.429378
# converged
# # weights:  851
# initial  value 11081.527917
# iter  10 value 10679.511240
# final  value 10679.160106
# converged
# # weights:  86
# initial  value 11439.954554
# iter  10 value 10717.338322
# final  value 10717.206405
# converged
# # weights:  171
# initial  value 17775.630265
# iter  10 value 10823.910806
# final  value 10823.904979
# converged
# # weights:  256
# initial  value 13551.664636
# final  value 10832.204988
# converged
# # weights:  341
# initial  value 11050.880189
# final  value 10815.555783
# converged
# # weights:  426
# initial  value 13525.729779
# iter  10 value 10753.964888
# iter  20 value 10746.139697
# final  value 10746.080183
# converged
# # weights:  511
# initial  value 12010.064111
# iter  10 value 10721.467813
# iter  20 value 10721.408752
# iter  30 value 10366.805512
# iter  40 value 10030.084469
# iter  50 value 9907.714589
# iter  60 value 9869.320328
# iter  70 value 9826.763081
# iter  80 value 9823.117804
# iter  90 value 9786.874610
# iter 100 value 9746.244823
# final  value 9746.244823
# stopped after 100 iterations
# # weights:  596
# initial  value 14947.243689
# iter  10 value 10557.294868
# iter  20 value 10554.523866
# iter  30 value 10554.490854
# iter  30 value 10554.490853
# iter  30 value 10554.490821
# final  value 10554.490821
# converged
# # weights:  681
# initial  value 21962.356351
# iter  10 value 10708.299627
# iter  20 value 10706.301864
# iter  30 value 10036.097893
# iter  40 value 9808.467574
# iter  50 value 9670.808343
# iter  60 value 9622.636198
# iter  70 value 9584.157436
# iter  80 value 9575.211727
# iter  90 value 9574.064096
# iter 100 value 9573.676356
# final  value 9573.676356
# stopped after 100 iterations
# # weights:  766
# initial  value 18504.361376
# iter  10 value 10684.985052
# iter  20 value 10679.450483
# iter  30 value 10462.896977
# iter  40 value 9928.382470
# iter  50 value 9879.930498
# iter  60 value 9814.080517
# iter  70 value 9693.919190
# iter  80 value 9595.097128
# iter  90 value 9484.533121
# iter 100 value 8396.535470
# final  value 8396.535470
# stopped after 100 iterations
# # weights:  851
# initial  value 22021.204517
# iter  10 value 10667.588355
# iter  20 value 10666.569882
# iter  30 value 10663.614412
# iter  40 value 10663.603524
# iter  50 value 10663.554770
# iter  60 value 10414.008533
# final  value 10414.007147
# converged
# # weights:  86
# initial  value 11914.461850
# final  value 10832.198793
# converged
# # weights:  171
# initial  value 13103.655256
# iter  10 value 10825.855316
# iter  20 value 10825.613383
# iter  30 value 10823.949240
# final  value 10823.920891
# converged
# # weights:  256
# initial  value 14054.314500
# iter  10 value 10812.830603
# iter  20 value 10812.803136
# iter  30 value 10640.229816
# iter  40 value 10282.785492
# iter  40 value 10282.785464
# iter  40 value 10282.785464
# final  value 10282.785464
# converged
# # weights:  341
# initial  value 13612.754396
# iter  10 value 10722.475431
# iter  20 value 10720.595661
# iter  30 value 10720.008119
# final  value 10720.000459
# converged
# # weights:  426
# initial  value 10712.953690
# iter  10 value 10247.097121
# iter  20 value 10030.620996
# iter  30 value 10024.088860
# iter  40 value 10020.020036
# iter  50 value 10016.687694
# iter  60 value 10016.608277
# iter  70 value 10016.514045
# iter  80 value 10016.463830
# iter  90 value 10010.654744
# iter 100 value 9996.907781
# final  value 9996.907781
# stopped after 100 iterations
# # weights:  511
# initial  value 14400.597431
# iter  10 value 10691.989896
# iter  20 value 10571.277563
# iter  30 value 10034.227276
# iter  40 value 10018.783879
# iter  50 value 10010.838588
# iter  60 value 10005.773299
# iter  70 value 10001.260182
# iter  80 value 9985.500526
# iter  90 value 9773.726871
# iter 100 value 9541.177761
# final  value 9541.177761
# stopped after 100 iterations
# # weights:  596
# initial  value 19392.815163
# iter  10 value 10779.223379
# iter  20 value 10769.520054
# final  value 10769.433392
# converged
# # weights:  681
# initial  value 10827.718545
# iter  10 value 10780.858049
# iter  20 value 10780.725069
# iter  30 value 10667.262669
# iter  40 value 10659.809346
# iter  50 value 10530.706721
# iter  60 value 10529.668109
# final  value 10529.665477
# converged
# # weights:  766
# initial  value 15824.881370
# iter  10 value 10778.144932
# final  value 10777.914176
# converged
# # weights:  851
# initial  value 15377.361809
# iter  10 value 10649.343385
# iter  20 value 10649.269042
# iter  30 value 10642.105245
# iter  40 value 10320.959570
# iter  50 value 9994.104705
# iter  60 value 9814.977098
# iter  70 value 9733.159210
# iter  80 value 9445.988796
# iter  90 value 8452.952603
# iter 100 value 7973.927260
# final  value 7973.927260
# stopped after 100 iterations
# # weights:  86
# initial  value 15321.004058
# iter  10 value 10608.562542
# final  value 10607.552734
# converged
# # weights:  171
# initial  value 17293.302253
# iter  10 value 10786.370215
# final  value 10786.327945
# converged
# # weights:  256
# initial  value 14115.252488
# iter  10 value 10832.639833
# iter  20 value 10832.363609
# iter  30 value 10221.517090
# iter  40 value 9953.590887
# iter  50 value 9880.012774
# iter  60 value 9778.132202
# iter  70 value 9700.778493
# iter  80 value 9442.240450
# iter  90 value 9342.061739
# iter 100 value 9310.660169
# final  value 9310.660169
# stopped after 100 iterations
# # weights:  341
# initial  value 14823.258679
# iter  10 value 10832.190866
# iter  20 value 10639.819078
# iter  30 value 10030.434143
# iter  40 value 10022.839659
# iter  50 value 10004.843893
# iter  60 value 10002.029119
# iter  70 value 10001.842720
# iter  80 value 9935.391909
# iter  90 value 9817.582320
# iter 100 value 9801.660431
# final  value 9801.660431
# stopped after 100 iterations
# # weights:  426
# initial  value 12025.255818
# iter  10 value 10781.026189
# final  value 10780.746453
# converged
# # weights:  511
# initial  value 11012.398219
# iter  10 value 10202.113708
# iter  20 value 10021.093230
# iter  30 value 9997.593298
# iter  40 value 9995.710942
# iter  50 value 9995.662578
# final  value 9995.299450
# converged
# # weights:  596
# initial  value 17009.685399
# iter  10 value 10609.103449
# iter  20 value 10607.582413
# final  value 10606.158287
# converged
# # weights:  681
# initial  value 13295.422927
# iter  10 value 9902.840444
# iter  20 value 9832.715623
# iter  30 value 9819.100883
# iter  40 value 9802.193934
# iter  50 value 9794.681895
# iter  60 value 9792.030727
# iter  70 value 9787.590459
# iter  80 value 9744.513495
# iter  90 value 9634.453065
# iter 100 value 9611.018249
# final  value 9611.018249
# stopped after 100 iterations
# # weights:  766
# initial  value 19206.706548
# iter  10 value 10776.433436
# iter  20 value 10623.874218
# iter  30 value 10623.737772
# iter  40 value 10328.342721
# iter  50 value 9885.762357
# iter  60 value 9671.987387
# iter  70 value 9595.767291
# iter  80 value 9591.453616
# iter  80 value 9591.453554
# final  value 9591.453554
# converged
# # weights:  851
# initial  value 14992.275099
# iter  10 value 10821.950771
# iter  20 value 10642.995363
# iter  30 value 10639.816523
# iter  40 value 10111.448953
# iter  50 value 10030.226773
# iter  60 value 10004.480919
# iter  70 value 9998.696261
# iter  80 value 9991.866064
# iter  90 value 9969.146235
# iter 100 value 9963.686040
# final  value 9963.686040
# stopped after 100 iterations
# # weights:  86
# initial  value 12754.318853
# iter  10 value 10832.196391
# final  value 10832.188423
# converged
# # weights:  171
# initial  value 16595.326992
# iter  10 value 10832.198540
# final  value 10832.188423
# converged
# # weights:  256
# initial  value 17872.372998
# iter  10 value 10832.211569
# iter  20 value 10138.602813
# iter  30 value 10010.850467
# iter  40 value 10002.916996
# iter  50 value 10001.698318
# iter  60 value 10000.287300
# iter  70 value 10000.278776
# iter  80 value 10000.065242
# iter  90 value 9997.700818
# final  value 9997.511097
# converged
# # weights:  341
# initial  value 11685.829258
# iter  10 value 10781.289203
# iter  20 value 10780.838497
# iter  30 value 10355.029766
# iter  40 value 10032.519768
# iter  50 value 10000.327517
# iter  60 value 9937.509963
# iter  70 value 9803.637006
# iter  80 value 9785.482906
# iter  90 value 9741.254457
# iter 100 value 9651.310535
# final  value 9651.310535
# stopped after 100 iterations
# # weights:  426
# initial  value 20307.435748
# iter  10 value 10815.691779
# iter  20 value 10815.616395
# iter  30 value 10088.886380
# iter  40 value 9952.560419
# iter  50 value 9910.984356
# iter  60 value 9895.089175
# iter  70 value 9839.296044
# iter  80 value 9791.505546
# iter  90 value 9784.981385
# iter 100 value 9777.218083
# final  value 9777.218083
# stopped after 100 iterations
# # weights:  511
# initial  value 10614.796768
# iter  10 value 10003.188112
# iter  20 value 9999.189353
# iter  30 value 9975.396861
# iter  40 value 9824.979415
# iter  50 value 8069.005323
# iter  60 value 7385.450421
# iter  70 value 7129.834261
# iter  80 value 7037.117193
# iter  90 value 6993.813412
# iter 100 value 6975.934109
# final  value 6975.934109
# stopped after 100 iterations
# # weights:  596
# initial  value 12146.832646
# iter  10 value 10724.417619
# iter  20 value 10724.167834
# iter  30 value 10501.741974
# iter  40 value 9939.719254
# iter  50 value 9917.472159
# iter  60 value 9913.721453
# iter  70 value 9857.158452
# iter  80 value 9832.335376
# iter  90 value 9798.488703
# iter 100 value 9692.165856
# final  value 9692.165856
# stopped after 100 iterations
# # weights:  681
# initial  value 14431.786896
# iter  10 value 10815.765837
# iter  20 value 10752.148627
# iter  30 value 10462.485844
# iter  40 value 10066.286929
# iter  50 value 10024.685182
# iter  60 value 9916.621295
# iter  70 value 9790.521051
# iter  80 value 9752.030032
# iter  90 value 9701.937544
# iter 100 value 9611.886820
# final  value 9611.886820
# stopped after 100 iterations
# # weights:  766
# initial  value 12270.687726
# iter  10 value 10815.752124
# iter  20 value 10815.611495
# iter  30 value 10182.838948
# iter  40 value 9915.006103
# iter  50 value 9803.721000
# iter  60 value 9780.128076
# iter  70 value 9775.089256
# iter  80 value 9772.185970
# iter  90 value 9735.148263
# iter 100 value 9631.021091
# final  value 9631.021091
# stopped after 100 iterations
# # weights:  851
# initial  value 11845.345873
# iter  10 value 10630.599360
# iter  20 value 10176.854148
# iter  30 value 10011.850242
# iter  40 value 10007.837834
# iter  50 value 10007.728471
# iter  60 value 10001.149132
# iter  70 value 9890.063614
# iter  80 value 9832.512294
# iter  90 value 9831.849643
# iter 100 value 9816.361165
# final  value 9816.361165
# stopped after 100 iterations
# # weights:  86
# initial  value 16093.975439
# iter  10 value 10832.196288
# final  value 10832.190198
# converged
# # weights:  171
# initial  value 16082.763211
# iter  10 value 10832.201213
# iter  20 value 10832.187290
# iter  20 value 10832.187288
# iter  20 value 10832.187288
# final  value 10832.187288
# converged
# # weights:  256
# initial  value 10864.789769
# iter  10 value 10800.567446
# iter  20 value 10222.223457
# iter  30 value 9851.191044
# iter  40 value 9779.138824
# iter  50 value 9719.845515
# iter  60 value 9618.402748
# iter  70 value 9601.679205
# iter  80 value 9594.192843
# iter  90 value 9592.292350
# iter 100 value 9587.963959
# final  value 9587.963959
# stopped after 100 iterations
# # weights:  341
# initial  value 13363.586085
# iter  10 value 10833.083597
# iter  20 value 10656.747899
# iter  30 value 10117.179573
# iter  40 value 9847.035684
# iter  50 value 9794.173661
# iter  60 value 9696.372965
# iter  70 value 9622.441542
# iter  80 value 9574.222867
# iter  90 value 9557.985824
# iter 100 value 9496.998767
# final  value 9496.998767
# stopped after 100 iterations
# # weights:  426
# initial  value 11879.774976
# iter  10 value 10829.716392
# iter  20 value 10829.537483
# iter  30 value 10500.018925
# iter  40 value 10203.139516
# iter  50 value 9872.959285
# iter  60 value 9697.579236
# iter  70 value 9521.406516
# iter  80 value 8717.698024
# iter  90 value 8013.311768
# iter 100 value 7631.112502
# final  value 7631.112502
# stopped after 100 iterations
# # weights:  511
# initial  value 28576.480531
# iter  10 value 10712.121609
# iter  20 value 10129.027353
# iter  30 value 10042.397105
# iter  40 value 10039.780046
# iter  50 value 10026.141685
# iter  60 value 10020.145204
# iter  70 value 10001.855670
# iter  80 value 9867.079961
# iter  90 value 9661.994376
# iter 100 value 9610.018802
# final  value 9610.018802
# stopped after 100 iterations
# # weights:  596
# initial  value 12515.600285
# iter  10 value 10037.822867
# iter  20 value 9928.499985
# iter  30 value 9922.595393
# iter  40 value 9879.570113
# iter  50 value 9869.094331
# iter  60 value 9862.122566
# iter  70 value 9860.390785
# iter  80 value 9859.864753
# iter  90 value 9844.840594
# iter 100 value 9834.706719
# final  value 9834.706719
# stopped after 100 iterations
# # weights:  681
# initial  value 12492.539155
# iter  10 value 10792.186413
# iter  20 value 10132.031306
# iter  30 value 10004.260850
# iter  40 value 9999.057523
# iter  50 value 9995.964677
# iter  60 value 9964.498445
# iter  70 value 9963.582699
# iter  80 value 9961.507553
# iter  90 value 9827.520165
# iter 100 value 9808.832019
# final  value 9808.832019
# stopped after 100 iterations
# # weights:  766
# initial  value 10921.795584
# iter  10 value 9954.125053
# iter  20 value 9942.102629
# iter  30 value 9941.627143
# iter  40 value 9941.234919
# iter  50 value 9940.441271
# iter  60 value 9800.971338
# iter  70 value 9792.017143
# iter  80 value 9738.035622
# iter  90 value 9723.553080
# iter 100 value 9699.649859
# final  value 9699.649859
# stopped after 100 iterations
# # weights:  851
# initial  value 10887.308036
# iter  10 value 10605.951467
# iter  20 value 10030.958726
# iter  30 value 10015.856759
# iter  40 value 10012.728272
# iter  50 value 9994.304947
# iter  60 value 9806.881064
# iter  70 value 9681.545416
# iter  80 value 9611.340959
# iter  90 value 9580.557087
# iter 100 value 9564.616483
# final  value 9564.616483
# stopped after 100 iterations
# # weights:  86
# initial  value 16565.783045
# iter  10 value 10799.534847
# iter  20 value 10799.131022
# iter  30 value 10430.859828
# iter  40 value 10142.332853
# iter  50 value 10087.381242
# iter  60 value 10069.393060
# iter  70 value 10058.002937
# iter  80 value 10038.996740
# iter  90 value 9911.627638
# iter 100 value 9444.480501
# final  value 9444.480501
# stopped after 100 iterations
# # weights:  171
# initial  value 11194.299020
# iter  10 value 10723.022664
# iter  20 value 10722.886506
# iter  30 value 10209.876798
# iter  40 value 10176.033179
# iter  50 value 9876.887166
# iter  60 value 9825.856288
# iter  70 value 9797.875177
# iter  80 value 9783.496032
# iter  90 value 9777.025163
# iter 100 value 9742.197082
# final  value 9742.197082
# stopped after 100 iterations
# # weights:  256
# initial  value 10870.416637
# iter  10 value 10682.691055
# iter  20 value 10437.525594
# iter  30 value 10117.504900
# iter  40 value 9929.141476
# iter  50 value 9921.446040
# iter  60 value 9857.680988
# iter  70 value 9785.945359
# iter  80 value 9719.635506
# iter  90 value 9701.735982
# iter 100 value 9689.783273
# final  value 9689.783273
# stopped after 100 iterations
# # weights:  341
# initial  value 12630.221140
# iter  10 value 10177.486356
# iter  20 value 9961.135537
# iter  30 value 9960.698041
# iter  40 value 9932.950702
# iter  50 value 9881.584805
# iter  60 value 9875.869821
# iter  70 value 9874.408472
# iter  80 value 9868.503454
# iter  90 value 9852.708023
# iter 100 value 9342.840352
# final  value 9342.840352
# stopped after 100 iterations
# # weights:  426
# initial  value 11258.786102
# iter  10 value 10671.537658
# iter  20 value 10617.064109
# iter  30 value 10228.930846
# iter  40 value 10016.844927
# iter  50 value 10015.514964
# iter  60 value 9862.355305
# iter  70 value 9827.830117
# iter  80 value 9810.634399
# iter  90 value 9780.326503
# iter 100 value 9762.380044
# final  value 9762.380044
# stopped after 100 iterations
# # weights:  511
# initial  value 10793.855898
# iter  10 value 10535.286508
# iter  20 value 10515.455977
# iter  30 value 10515.187283
# final  value 10512.984728
# converged
# # weights:  596
# initial  value 10887.264504
# iter  10 value 10624.982511
# iter  20 value 10603.381672
# iter  30 value 10603.110867
# iter  40 value 10211.680606
# iter  50 value 10015.686718
# iter  60 value 9987.741747
# iter  70 value 9865.493578
# iter  80 value 9786.750386
# iter  90 value 9756.745592
# iter 100 value 9669.921910
# final  value 9669.921910
# stopped after 100 iterations
# # weights:  681
# initial  value 11462.213270
# iter  10 value 10758.179284
# iter  20 value 10757.117219
# iter  30 value 10757.018999
# iter  30 value 10757.018993
# iter  30 value 10757.018943
# final  value 10757.018943
# converged
# # weights:  766
# initial  value 11010.882543
# iter  10 value 10672.955231
# iter  20 value 10672.461037
# iter  30 value 10508.960533
# iter  40 value 10174.019531
# iter  50 value 9979.746506
# iter  60 value 9905.866429
# iter  70 value 9640.657843
# iter  80 value 9468.787008
# iter  90 value 9408.461004
# iter 100 value 9400.730000
# final  value 9400.730000
# stopped after 100 iterations
# # weights:  851
# initial  value 16803.799385
# iter  10 value 10789.880895
# iter  20 value 10787.988390
# iter  30 value 10350.303904
# iter  40 value 10208.658967
# iter  50 value 9675.812033
# iter  60 value 9092.828755
# iter  70 value 8786.027027
# iter  80 value 8176.053444
# iter  90 value 8069.617902
# iter 100 value 8033.366549
# final  value 8033.366549
# stopped after 100 iterations
# # weights:  86
# initial  value 15298.302190
# iter  10 value 10832.209214
# final  value 10832.197989
# converged
# # weights:  171
# initial  value 15435.784825
# iter  10 value 10591.378351
# iter  20 value 10104.134788
# iter  30 value 10074.763555
# iter  40 value 10060.845110
# iter  50 value 10060.573435
# iter  60 value 10060.462528
# iter  70 value 10060.445656
# final  value 10060.444904
# converged
# # weights:  256
# initial  value 18672.299966
# iter  10 value 10718.117422
# iter  20 value 10707.951142
# iter  30 value 10051.250260
# iter  40 value 10050.165295
# iter  50 value 9970.363743
# iter  60 value 9641.921624
# iter  70 value 9547.096978
# iter  80 value 9540.612167
# iter  90 value 8999.284367
# iter 100 value 7589.100758
# final  value 7589.100758
# stopped after 100 iterations
# # weights:  341
# initial  value 18977.273651
# iter  10 value 10832.206831
# iter  20 value 10832.188844
# iter  20 value 10832.188819
# iter  20 value 10832.188813
# final  value 10832.188813
# converged
# # weights:  426
# initial  value 13949.174570
# iter  10 value 10788.296601
# iter  20 value 10356.940627
# iter  30 value 10051.691203
# iter  40 value 9774.166871
# iter  50 value 9709.522237
# iter  60 value 9639.216153
# iter  70 value 9606.116235
# iter  80 value 9603.708021
# iter  90 value 9590.222507
# iter 100 value 9586.759157
# final  value 9586.759157
# stopped after 100 iterations
# # weights:  511
# initial  value 12976.491054
# iter  10 value 10778.813494
# iter  20 value 10059.643326
# iter  30 value 9893.943516
# iter  40 value 9805.525638
# iter  50 value 9798.653129
# iter  60 value 9783.545420
# iter  70 value 9778.884219
# iter  80 value 9771.819281
# iter  90 value 9731.912891
# iter 100 value 9669.354715
# final  value 9669.354715
# stopped after 100 iterations
# # weights:  596
# initial  value 10885.633351
# iter  10 value 10696.000961
# iter  20 value 10452.251818
# iter  30 value 10096.900215
# iter  40 value 9974.698142
# iter  50 value 9933.521647
# iter  60 value 9858.160281
# iter  70 value 9826.363141
# iter  80 value 9772.108989
# iter  90 value 9759.681043
# iter 100 value 9708.264161
# final  value 9708.264161
# stopped after 100 iterations
# # weights:  681
# initial  value 11262.711480
# iter  10 value 10813.361740
# iter  20 value 10253.172258
# iter  30 value 10203.691020
# iter  40 value 10196.242943
# iter  50 value 10192.793636
# iter  60 value 10190.694649
# iter  70 value 10189.205578
# iter  80 value 10066.306844
# iter  90 value 9964.870704
# iter 100 value 9795.118293
# final  value 9795.118293
# stopped after 100 iterations
# # weights:  766
# initial  value 17108.018700
# iter  10 value 10782.741566
# iter  20 value 10062.255513
# iter  30 value 9916.325450
# iter  40 value 9835.747148
# iter  50 value 9737.202285
# iter  60 value 9615.783600
# iter  70 value 9391.963046
# iter  80 value 8906.784365
# iter  90 value 7707.400036
# iter 100 value 7327.165631
# final  value 7327.165631
# stopped after 100 iterations
# # weights:  851
# initial  value 28302.797122
# iter  10 value 10760.080195
# iter  20 value 10688.856184
# iter  30 value 10146.447910
# iter  40 value 9957.088070
# iter  50 value 9906.126761
# iter  60 value 9809.663611
# iter  70 value 9806.028410
# iter  80 value 9766.599481
# iter  90 value 9736.211967
# iter 100 value 9614.667136
# final  value 9614.667136
# stopped after 100 iterations
# # weights:  86
# initial  value 11966.693180
# iter  10 value 10823.579971
# final  value 10823.571220
# converged
# # weights:  171
# initial  value 16781.114514
# final  value 10833.292614
# converged
# # weights:  256
# initial  value 20421.064015
# iter  10 value 10818.001713
# final  value 10818.001351
# converged
# # weights:  341
# initial  value 12693.735786
# final  value 10833.295262
# converged
# # weights:  426
# initial  value 11557.180540
# final  value 10819.401875
# converged
# # weights:  511
# initial  value 11022.236298
# iter  10 value 10727.576708
# iter  20 value 10727.177731
# iter  20 value 10727.177688
# iter  20 value 10727.177688
# final  value 10727.177688
# converged
# # weights:  596
# initial  value 12057.042621
# iter  10 value 10772.132126
# final  value 10771.986986
# converged
# # weights:  681
# initial  value 12756.872723
# final  value 10833.301367
# converged
# # weights:  766
# initial  value 14773.101371
# iter  10 value 10716.161658
# iter  20 value 10304.171174
# iter  30 value 10015.678685
# iter  40 value 9881.926864
# iter  50 value 9825.354764
# iter  60 value 9720.973609
# iter  70 value 9708.250862
# iter  80 value 9642.336874
# iter  90 value 9609.882970
# iter 100 value 9600.240604
# final  value 9600.240604
# stopped after 100 iterations
# # weights:  851
# initial  value 16814.800651
# final  value 10816.619926
# converged
# # weights:  86
# initial  value 10943.468202
# final  value 10833.292596
# converged
# # weights:  171
# initial  value 13957.004459
# iter  10 value 10819.401376
# final  value 10819.399322
# converged
# # weights:  256
# initial  value 12255.248620
# final  value 10833.296489
# converged
# # weights:  341
# initial  value 17273.974180
# final  value 10816.620538
# converged
# # weights:  426
# initial  value 13259.822443
# iter  10 value 10827.758312
# final  value 10827.753514
# converged
# # weights:  511
# initial  value 10879.651658
# iter  10 value 10666.925212
# iter  20 value 10666.826868
# final  value 10666.813767
# converged
# # weights:  596
# initial  value 13178.412510
# iter  10 value 10727.896714
# iter  20 value 10668.232580
# iter  30 value 10643.728573
# iter  40 value 10538.296585
# iter  50 value 10524.719481
# iter  60 value 10018.320478
# iter  70 value 9943.422479
# iter  80 value 9794.124281
# iter  90 value 9696.348052
# iter 100 value 9647.691582
# final  value 9647.691582
# stopped after 100 iterations
# # weights:  681
# initial  value 11037.692405
# iter  10 value 10744.442122
# final  value 10744.004488
# converged
# # weights:  766
# initial  value 42053.287482
# final  value 10806.888602
# converged
# # weights:  851
# initial  value 23837.448464
# iter  10 value 10784.722336
# iter  20 value 10191.445364
# iter  30 value 10018.341726
# iter  40 value 9979.610042
# iter  50 value 9942.651356
# final  value 9913.559466
# converged
# # weights:  86
# initial  value 14112.379194
# final  value 10833.293628
# converged
# # weights:  171
# initial  value 15866.452034
# iter  10 value 10823.595540
# final  value 10823.592934
# converged
# # weights:  256
# initial  value 13985.809610
# iter  10 value 10779.106513
# iter  20 value 10716.205413
# iter  30 value 10019.482701
# iter  40 value 9939.421937
# iter  50 value 9928.272114
# iter  60 value 9776.951772
# iter  70 value 9597.953325
# iter  80 value 9366.795626
# iter  90 value 8977.250161
# iter 100 value 7886.559944
# final  value 7886.559944
# stopped after 100 iterations
# # weights:  341
# initial  value 17839.504571
# iter  10 value 10739.842114
# final  value 10689.297761
# converged
# # weights:  426
# initial  value 16988.945671
# final  value 10833.308578
# converged
# # weights:  511
# initial  value 10982.531435
# iter  10 value 9980.835974
# iter  20 value 9970.668598
# iter  30 value 9970.629516
# iter  40 value 9967.110912
# iter  50 value 9967.076435
# iter  60 value 9962.027822
# iter  70 value 9953.513082
# final  value 9953.231322
# converged
# # weights:  596
# initial  value 12781.429705
# final  value 10816.652902
# converged
# # weights:  681
# initial  value 11540.932194
# iter  10 value 10788.806841
# iter  20 value 10788.774384
# final  value 10788.761400
# converged
# # weights:  766
# initial  value 10842.681992
# final  value 10732.584711
# converged
# # weights:  851
# initial  value 14127.935944
# iter  10 value 10736.122029
# iter  20 value 10662.645793
# iter  30 value 10630.361328
# iter  40 value 10621.152334
# iter  50 value 10079.960109
# iter  60 value 9966.067185
# iter  70 value 9823.876634
# iter  80 value 9701.524741
# iter  90 value 9638.499683
# iter 100 value 9608.804911
# final  value 9608.804911
# stopped after 100 iterations
# # weights:  86
# initial  value 12714.136747
# iter  10 value 10672.604323
# iter  20 value 10649.859346
# final  value 10649.859050
# converged
# # weights:  171
# initial  value 13293.952404
# iter  10 value 10686.983013
# iter  20 value 10685.121925
# iter  20 value 10685.121898
# iter  20 value 10685.121898
# final  value 10685.121898
# converged
# # weights:  256
# initial  value 18422.888802
# iter  10 value 10830.565700
# final  value 10830.562653
# converged
# # weights:  341
# initial  value 12026.057672
# iter  10 value 10823.622045
# final  value 10823.621162
# converged
# # weights:  426
# initial  value 17554.244061
# final  value 10833.321897
# converged
# # weights:  511
# initial  value 17813.009252
# iter  10 value 10811.104209
# iter  20 value 10669.472762
# iter  30 value 10066.077254
# iter  40 value 9996.232575
# iter  50 value 9897.373996
# iter  60 value 9749.152731
# iter  70 value 9383.926232
# iter  80 value 9197.364616
# iter  90 value 9170.331217
# iter 100 value 9149.612717
# final  value 9149.612717
# stopped after 100 iterations
# # weights:  596
# initial  value 14349.044234
# iter  10 value 10690.261302
# final  value 10689.310343
# converged
# # weights:  681
# initial  value 21698.599057
# iter  10 value 10697.795246
# iter  20 value 10666.781868
# iter  20 value 10666.781789
# iter  20 value 10666.781788
# final  value 10666.781788
# converged
# # weights:  766
# initial  value 14164.775092
# iter  10 value 10754.660363
# iter  20 value 10662.177857
# iter  30 value 10655.362407
# final  value 10655.358660
# converged
# # weights:  851
# initial  value 11763.287461
# iter  10 value 10732.831090
# iter  20 value 10265.820319
# iter  30 value 10098.973230
# iter  40 value 9949.874279
# iter  50 value 9684.074778
# iter  60 value 9410.794280
# iter  70 value 9299.163118
# iter  80 value 9254.329865
# iter  90 value 9230.031353
# iter 100 value 9225.048784
# final  value 9225.048784
# stopped after 100 iterations
# # weights:  86
# initial  value 16687.979833
# iter  10 value 10764.075966
# final  value 10763.653619
# converged
# # weights:  171
# initial  value 12920.886233
# iter  10 value 10823.656074
# final  value 10823.653592
# converged
# # weights:  256
# initial  value 11639.901964
# iter  10 value 10717.724006
# final  value 10716.025720
# converged
# # weights:  341
# initial  value 11212.167848
# iter  10 value 10080.795961
# iter  20 value 9903.031798
# iter  30 value 9760.071900
# iter  40 value 9748.781707
# iter  50 value 9746.742720
# iter  60 value 9744.198262
# iter  70 value 9743.392455
# iter  80 value 9739.916145
# iter  90 value 9739.640311
# iter 100 value 9723.819843
# final  value 9723.819843
# stopped after 100 iterations
# # weights:  426
# initial  value 12257.331636
# iter  10 value 10267.620412
# iter  20 value 10035.682581
# iter  30 value 9949.041825
# iter  40 value 9912.523747
# iter  50 value 9850.887349
# iter  60 value 9764.639872
# iter  70 value 9711.617847
# iter  80 value 9648.266130
# iter  90 value 9600.506464
# iter 100 value 9580.755299
# final  value 9580.755299
# stopped after 100 iterations
# # weights:  511
# initial  value 17038.248728
# iter  10 value 10816.710502
# iter  20 value 10816.658724
# final  value 10816.656478
# converged
# # weights:  596
# initial  value 18083.777851
# iter  10 value 10011.157576
# iter  20 value 9978.688385
# iter  30 value 9978.546397
# iter  40 value 9970.986554
# iter  50 value 9947.495802
# iter  60 value 9784.726281
# iter  70 value 9724.756123
# iter  80 value 9706.884723
# iter  90 value 9660.631145
# iter 100 value 9645.568930
# final  value 9645.568930
# stopped after 100 iterations
# # weights:  681
# initial  value 17014.503660
# iter  10 value 10818.126389
# iter  20 value 10818.045747
# iter  30 value 10151.629119
# iter  40 value 9870.874306
# iter  50 value 9810.517285
# iter  60 value 9743.126919
# iter  70 value 9719.036551
# iter  80 value 9616.627807
# iter  90 value 9589.874090
# iter 100 value 9585.194753
# final  value 9585.194753
# stopped after 100 iterations
# # weights:  766
# initial  value 10925.767162
# iter  10 value 10107.723438
# iter  20 value 9874.069276
# iter  30 value 9754.508943
# iter  40 value 9751.630643
# iter  50 value 9742.064242
# iter  60 value 9713.424394
# iter  70 value 9666.801758
# iter  80 value 9632.058798
# iter  90 value 9604.905689
# iter 100 value 9597.155665
# final  value 9597.155665
# stopped after 100 iterations
# # weights:  851
# initial  value 18046.816853
# iter  10 value 10816.766836
# iter  20 value 10816.646383
# iter  30 value 10376.989366
# iter  40 value 9839.107147
# iter  50 value 9753.625145
# iter  60 value 9713.034077
# iter  70 value 9710.164341
# iter  80 value 9694.885527
# iter  90 value 9659.545748
# iter 100 value 9612.503664
# final  value 9612.503664
# stopped after 100 iterations
# # weights:  86
# initial  value 12812.628439
# final  value 10833.307788
# converged
# # weights:  171
# initial  value 11780.472004
# iter  10 value 10833.292680
# final  value 10833.290866
# converged
# # weights:  256
# initial  value 11548.715901
# iter  10 value 10804.245645
# iter  20 value 10616.658985
# iter  30 value 10614.795124
# iter  40 value 10003.296616
# iter  50 value 9998.641356
# iter  60 value 9998.635043
# iter  60 value 9998.635043
# iter  60 value 9998.635042
# final  value 9998.635042
# converged
# # weights:  341
# initial  value 12240.571792
# iter  10 value 10816.746455
# iter  20 value 10816.705267
# iter  30 value 10582.231956
# iter  40 value 10168.844386
# iter  50 value 10041.007611
# iter  60 value 9931.606301
# iter  70 value 9857.120201
# iter  80 value 9731.465113
# iter  90 value 9381.259396
# iter 100 value 9157.749322
# final  value 9157.749322
# stopped after 100 iterations
# # weights:  426
# initial  value 10900.967315
# iter  10 value 10833.298526
# iter  20 value 10833.148853
# iter  30 value 10512.383974
# iter  40 value 10112.024749
# iter  50 value 9534.997465
# iter  60 value 9139.952458
# iter  70 value 8927.511138
# iter  80 value 8058.493391
# iter  90 value 7565.484392
# iter 100 value 7394.238316
# final  value 7394.238316
# stopped after 100 iterations
# # weights:  511
# initial  value 17127.574085
# iter  10 value 10717.782426
# iter  20 value 10575.342731
# iter  30 value 10526.238587
# iter  40 value 10029.775088
# iter  50 value 9969.663864
# iter  60 value 9964.389743
# iter  70 value 9963.389572
# iter  80 value 9963.001424
# iter  90 value 9962.884529
# iter 100 value 9961.518188
# final  value 9961.518188
# stopped after 100 iterations
# # weights:  596
# initial  value 25472.699567
# iter  10 value 10833.346655
# final  value 10833.307817
# converged
# # weights:  681
# initial  value 10988.443915
# iter  10 value 10643.765715
# iter  20 value 10643.684472
# iter  30 value 10232.398319
# iter  40 value 9846.096717
# iter  50 value 9652.462600
# iter  60 value 9575.572365
# iter  70 value 9480.108660
# iter  80 value 9369.663546
# iter  90 value 9115.580472
# iter 100 value 8427.749104
# final  value 8427.749104
# stopped after 100 iterations
# # weights:  766
# initial  value 34230.879727
# iter  10 value 10777.136140
# iter  20 value 10501.629082
# iter  30 value 10214.953709
# iter  40 value 10024.095813
# iter  50 value 9992.194714
# final  value 9992.184147
# converged
# # weights:  851
# initial  value 12502.895105
# iter  10 value 10678.934684
# iter  20 value 10625.105011
# iter  30 value 10624.976152
# iter  40 value 10094.205999
# iter  50 value 10018.293314
# iter  60 value 9865.252603
# iter  70 value 9769.457383
# iter  80 value 9681.073892
# iter  90 value 9657.736246
# iter 100 value 9627.526887
# final  value 9627.526887
# stopped after 100 iterations
# # weights:  86
# initial  value 13228.007631
# iter  10 value 10697.894557
# iter  20 value 10641.536976
# iter  30 value 10066.944231
# iter  40 value 9841.611740
# iter  50 value 9758.720204
# iter  60 value 9522.767632
# iter  70 value 7785.088487
# iter  80 value 7073.551899
# iter  90 value 6897.835092
# iter 100 value 6787.422489
# final  value 6787.422489
# stopped after 100 iterations
# # weights:  171
# initial  value 13045.666724
# iter  10 value 10833.304818
# final  value 10833.302324
# converged
# # weights:  256
# initial  value 12700.814823
# iter  10 value 10719.216371
# final  value 10672.631536
# converged
# # weights:  341
# initial  value 24838.787428
# iter  10 value 10796.125893
# iter  20 value 10795.853360
# final  value 10795.849130
# converged
# # weights:  426
# initial  value 22341.699727
# iter  10 value 10558.460087
# iter  20 value 10557.351776
# iter  30 value 10477.956389
# iter  40 value 10152.723521
# iter  50 value 9944.362961
# iter  60 value 9896.141647
# iter  70 value 9890.103340
# iter  80 value 9837.522371
# iter  90 value 9797.667594
# iter 100 value 9776.560628
# final  value 9776.560628
# stopped after 100 iterations
# # weights:  511
# initial  value 24282.435473
# iter  10 value 10823.833101
# iter  20 value 10713.679178
# iter  30 value 10643.039925
# iter  40 value 10109.136024
# iter  50 value 9846.102622
# iter  60 value 9663.101811
# iter  70 value 9615.020301
# iter  80 value 9608.739125
# iter  90 value 9596.644107
# iter 100 value 9592.152106
# final  value 9592.152106
# stopped after 100 iterations
# # weights:  596
# initial  value 18309.040037
# iter  10 value 10675.677758
# iter  20 value 10675.231279
# iter  30 value 10660.783857
# iter  40 value 10611.209497
# iter  50 value 9974.523019
# iter  60 value 9872.735919
# iter  70 value 9764.693542
# iter  80 value 9570.528460
# iter  90 value 9350.734741
# iter 100 value 8437.540135
# final  value 8437.540135
# stopped after 100 iterations
# # weights:  681
# initial  value 13859.841895
# iter  10 value 10804.448451
# iter  20 value 10381.531336
# iter  30 value 9934.345174
# iter  40 value 9920.535476
# iter  50 value 9920.315027
# iter  60 value 9920.278843
# iter  70 value 9847.205313
# iter  80 value 9777.676233
# iter  90 value 9695.025562
# iter 100 value 9615.658622
# final  value 9615.658622
# stopped after 100 iterations
# # weights:  766
# initial  value 13820.079472
# iter  10 value 10607.020625
# iter  20 value 10510.639555
# iter  30 value 10033.016778
# iter  40 value 9967.693154
# iter  50 value 9921.937661
# iter  60 value 9799.167319
# iter  70 value 9786.004430
# iter  80 value 9759.849033
# iter  90 value 9679.602386
# iter 100 value 9645.005581
# final  value 9645.005581
# stopped after 100 iterations
# # weights:  851
# initial  value 14673.600730
# iter  10 value 10818.251628
# iter  20 value 10818.062360
# iter  30 value 10043.764440
# iter  40 value 10011.011466
# iter  50 value 9819.348299
# iter  60 value 9807.466319
# iter  70 value 9803.153112
# final  value 9801.899242
# converged
# # weights:  86
# initial  value 12706.195757
# iter  10 value 10833.298113
# iter  20 value 10708.485589
# iter  30 value 10702.379312
# final  value 10702.367477
# converged
# # weights:  171
# initial  value 13743.806854
# iter  10 value 10833.301810
# iter  20 value 10833.291544
# iter  20 value 10833.291542
# iter  20 value 10833.291542
# final  value 10833.291542
# converged
# # weights:  256
# initial  value 10962.244530
# iter  10 value 10826.689526
# iter  20 value 10396.961864
# final  value 10292.214605
# converged
# # weights:  341
# initial  value 13159.853060
# iter  10 value 10678.946051
# final  value 10668.458802
# converged
# # weights:  426
# initial  value 13750.014826
# iter  10 value 10833.314530
# iter  20 value 10833.292529
# iter  30 value 10831.854850
# iter  40 value 10681.518753
# iter  40 value 10681.518752
# iter  50 value 10680.454021
# iter  60 value 10678.356251
# iter  60 value 10678.356250
# iter  70 value 9784.635300
# iter  80 value 9667.061089
# iter  90 value 9644.972829
# iter 100 value 9635.387060
# final  value 9635.387060
# stopped after 100 iterations
# # weights:  511

# %% [markdown]
# ### Save the results

# %%
# Bind results
mlp_pred_results <- list(cps_res = cps_res, adult_res = adult_res)
# Save the results to an RData file 
save(mlp_pred_results, file = paste0(dirname, "/results/mlp_pred_results.RData"))

# %% [markdown]
# # Boosting prediction function

# %%
install.packages("xgboost")
# Out:
# Die heruntergeladenen Bin"arpakete sind in
# 	/var/folders/kj/dkjqkk2n3wq2zfbttgdpjrj80000gn/T//RtmpOTcxAJ/downloaded_packages

# %%
list_of_packages <- c ("synthpop", "insight", "party", "dplyr", "rpart", "rpart.plot", "randomForest", "pROC", "caret", "pracma", "here", "Hmisc", "randomForest", "caret", "xgboost", "data.table")

lapply(list_of_packages, FUN= function(X){
  do.call("require", list(X))
})
# Out:
# Lade n"otiges Paket: synthpop
#
# Find out more at https://www.synthpop.org.uk/
#
# Lade n"otiges Paket: insight
#
# Lade n"otiges Paket: party
#
# Lade n"otiges Paket: grid
#
# Lade n"otiges Paket: mvtnorm
#
# Lade n"otiges Paket: modeltools
#
# Lade n"otiges Paket: stats4
#
# Lade n"otiges Paket: strucchange
#
# Lade n"otiges Paket: zoo
#
#
# Attache Paket: 'zoo'
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     as.Date, as.Date.numeric
#
#
# Lade n"otiges Paket: sandwich
#
# Lade n"otiges Paket: dplyr
#
#
# Attache Paket: 'dplyr'
#
#
# Das folgende Objekt ist maskiert 'package:party':
#
#     where
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     filter, lag
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Lade n"otiges Paket: rpart
#
# Lade n"otiges Paket: rpart.plot
#
# Lade n"otiges Paket: randomForest
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attache Paket: 'randomForest'
#
#
# Das folgende Objekt ist maskiert 'package:dplyr':
#
#     combine
#
#
# Lade n"otiges Paket: pROC
#
# Type 'citation("pROC")' for a citation.
#
#
# Attache Paket: 'pROC'
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     cov, smooth, var
#
#
# Lade n"otiges Paket: caret
#
# Lade n"otiges Paket: ggplot2
#
#
# Attache Paket: 'ggplot2'
#
#
# Das folgende Objekt ist maskiert 'package:randomForest':
#
#     margin
#
#
# Lade n"otiges Paket: lattice
#
# Lade n"otiges Paket: pracma
#
# Lade n"otiges Paket: here
#
# here() starts at /Users/emmafoessing/Documents/Master/MA/Code/Master-Thesis
#
# Lade n"otiges Paket: Hmisc
#
#
# Attache Paket: 'Hmisc'
#
#
# Das folgende Objekt ist maskiert 'package:pracma':
#
#     ceil
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     src, summarize
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     format.pval, units
#
#
# Lade n"otiges Paket: xgboost
#
#
# Attache Paket: 'xgboost'
#
#
# Das folgende Objekt ist maskiert 'package:dplyr':
#
#     slice
#
#
# Lade n"otiges Paket: data.table
#
#
# Attache Paket: 'data.table'
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     between, first, last
#
#
# Die folgenden Objekte sind maskiert von 'package:zoo':
#
#     yearmon, yearqtr
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE
#
# [[8]]
# [1] TRUE
#
# [[9]]
# [1] TRUE
#
# [[10]]
# [1] TRUE
#
# [[11]]
# [1] TRUE
#
# [[12]]
# [1] TRUE
#
# [[13]]
# [1] TRUE
#
# [[14]]
# [1] TRUE
#
# [[15]]
# [1] TRUE
#
# [[16]]
# [1] TRUE

# %% [markdown]
# ## Data

# %%
# directory
directory <- "/Users/emmafoessing/Documents/Master/MA/Code/Master-Thesis"
load(paste0(directory, "/cpspop.RData"))
adult <- read.csv(paste0(directory, "/adult_preprocessed.csv"))

# %%
# delete NAs
adult[adult == "?"] <- NA
adult <- na.omit(adult)

adult$workclass <- as.factor(adult$workclass)
adult$education <- as.factor(adult$education)
adult$marital_status <- as.factor(adult$marital_status)
adult$relationship <- as.factor(adult$relationship)
adult$race <- as.factor(adult$race)
adult$sex <- as.factor(adult$sex)
adult$native_country <- as.factor(adult$native_country)
adult$income <- as.factor(adult$income)

# %%
head(adult)
# Out:
#   age workclass fnlwgt education marital_status occupation relationship race
# 1 82  2         132870 11        6              3          1            4
# 2 54  2         140359 5         0              6          4            4
# 3 41  2         264663 15        5              9          3            4
# 4 34  2         216864 11        0              7          4            4
# 5 38  2         150601 0         5              0          4            4
# 6 74  5          88638 10        4              9          2            4
#   sex capital_gain capital_loss hours_per_week native_country income
# 1 0   0            4356         18             38             <=50K
# 2 0   0            3900         40             38             <=50K
# 3 0   0            3900         40             38             <=50K
# 4 0   0            3770         45             38             <=50K
# 5 1   0            3770         40             38             <=50K
# 6 0   0            3683         20             38             >50K

# %% [markdown]
# ### Helper functions

# %%
## eval cont targets
evaluation_metrics_cont <- function(predictions, test_set){
  MAE <- mean(abs(predictions - test_set$income))
  MSE <- mean((predictions - test_set$income)^2)
  RMSE <- sqrt(MSE)

  SS_res <- sum((test_set$income - predictions)^2)
  SS_tot <- sum((test_set$income - mean(test_set$income))^2)
  R_squared <- 1 - (SS_res / SS_tot)

  MAPE <- mean(abs((test_set$income - predictions) / test_set$income)) * 100

  # Create the dataframe
  metrics_df <- data.frame(
        MAE = MAE, 
        MSE = MSE, 
        RMSE = RMSE,
        R_squared = R_squared, 
        MAPE = MAPE)

  return(metrics_df)
}

# %%
## eval factored targets
evaluation_metrics_factor <- function(predictions, test_set){
    # confusion matrix for the prediction on original data
    cm <- confusionMatrix(predictions, test_set$income,
                mode = "everything")

    # saving evaluation metrics
    accuracy <- cm$overall['Accuracy']
    f1 <- cm$byClass['F1']
    sens <- cm$byClass['Sensitivity']
    spec <- cm$byClass['Specificity']

    # Create the dataframe
    metrics_df <- data.frame(
        Accuracy = accuracy, 
        F1 = f1, 
        Sensitivity = sens, 
        Specificity = spec
    )
    
    return(metrics_df)
}

# %%
convert_to_numeric_matrix <- function(df) {
  # Convert factors to numeric
  df[] <- lapply(df, function(col) {
    if (is.factor(col)) {
      return(as.numeric(col))
    } else {
      return(col)
    }
  })
  
  # Convert the entire data frame to a matrix
  matrix_data <- as.matrix(df)
  return(matrix_data)
}

# %%
xgb_pred <- function(data, outer_folds, inner_folds, nrounds_steps, max_depth_steps, eta_steps, gamma_steps, colsample_bytree_steps, min_child_weight_steps, subsample_steps) { ############adjust##############

    # Adjust evaluation metric to fit both numeric and factored targets
    summaryFunctionType <- if (is.numeric(data$income)) defaultSummary else multiClassSummary
    
    # Set control arguments
    outer_control <- trainControl(method = "cv", number = outer_folds,
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)
        
    inner_control <- trainControl(method = "cv", number = inner_folds, 
                                  summaryFunction = summaryFunctionType,
                                  verboseIter = FALSE,
                                  allowParallel = TRUE)

    # Define the parameter grid for tuning
    tunegrid <- expand.grid(
        nrounds = seq(50, 150, length.out = nrounds_steps),
        max_depth = round(seq(3, 9, length.out = max_depth_steps)),
        eta = seq(0.01, 0.3, length.out = eta_steps),
        gamma = seq(0, 0.2, length.out = gamma_steps),
        colsample_bytree = seq(0.5, 1, length.out = colsample_bytree_steps),
        min_child_weight = seq(1, 10, length.out = min_child_weight_steps),
        subsample = seq(0.5, 1, length.out = subsample_steps)
    )
    # alternatives for smaller grid:
        #gamma = 0,  # Default value
        #colsample_bytree = 0.8,  # Default value
        #min_child_weight = 1,  # Default value
        #subsample = 0.8  # Default value


    # Initialize variables to store results
    outer_results <- list()

    outer_cv_folds <- createFolds(data$income, k = outer_folds)
    
    # Outer loop: Cross-validation for model evaluation
    for (i in seq_along(outer_cv_folds)) {
        
        # Split data into outer folds
        outer_test_index <- outer_cv_folds[[i]]
        outer_testData <- data[outer_test_index,]
        outer_trainData <- data[-outer_test_index,]
        
        # Convert data for xgboost
        train_X <- convert_to_numeric_matrix(outer_trainData[, !colnames(outer_trainData) %in% 'income'])
        train_y <- outer_trainData$income
        
        val_X <- convert_to_numeric_matrix(outer_testData[, !colnames(outer_testData) %in% 'income'])
        val_y <- outer_testData$income
        
        train_dmatrix <- xgb.DMatrix(data = train_X, label = train_y)
        val_dmatrix <- xgb.DMatrix(data = val_X, label = val_y)

        # Hyperparameter tuning using inner CV
        model <- caret::train(x = train_X, 
                              y = train_y,
                              method = "xgbTree", ############adjust##############
                              tuneGrid = tunegrid, 
                              trControl = inner_control,
                              verbose = FALSE)
        
        # Store the best hyperparameters
        best_hyperparameters <- model$bestTune

        # Train the final model on the outer training set with the best hyperparameters
        final_model <- caret::train(x = train_X, 
                                    y = train_y, 
                                    method = "xgbTree", ############adjust##############
                                    tuneGrid = best_hyperparameters,
                                    trControl = outer_control,
                                    verbose = FALSE)

        # Testing the final model on the outer test set
        predictions <- predict(model, newdata = val_X, iteration_range = c(1, model$bestTune$nrounds))############adjust##############

        
        if (is.numeric(data$income)) {
            eval <- evaluation_metrics_cont(predictions, outer_testData)
        } else if (is.factor(data$income)) {
            eval <- evaluation_metrics_factor(predictions, outer_testData)
        } else {
            stop("The predicted target has to be numeric or factor.")
        }

        # Store the evaluation metrics for this outer fold
        outer_results[[i]] <- eval
    }

    # Average the evaluation metrics over the outer folds
    eval_avg_outer_folds <- do.call(rbind, outer_results) %>%
                            summarise(across(everything(), mean, na.rm = TRUE))

    

    # Return the average evaluation metrics
    return(eval_avg_outer_folds)
}

# %%
cps_res <- xgb_pred(cpspop, 2, 2, 2, 2, 2, 2, 2, 2, 2)
# Out:
# [16:08:59] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:00] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:00] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:01] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:03] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:04] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:06] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:07] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:07] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:08] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:09] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:10] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:11] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:12] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:14] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:15] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:18] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:20] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:22] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:24] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:27] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:30] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:34] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:37] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:39] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:41] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:43] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:45] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:48] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:51] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:54] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:57] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:58] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:59] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:09:59] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:00] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:01] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:02] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:03] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:04] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:04] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:05] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:06] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:06] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:07] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:08] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:09] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:10] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:12] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:13] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:15] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:17] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:20] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:23] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:26] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:28] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:30] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:32] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:34] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:36] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:39] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:42] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:47] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:51] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:52] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:52] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:53] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:53] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:54] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:55] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:56] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:57] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:58] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:58] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:10:59] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:00] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:02] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:03] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:04] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:05] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:07] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:09] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:11] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:13] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:16] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:19] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:22] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:25] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:27] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:29] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:31] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:32] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:36] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:39] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:42] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:45] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:45] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:46] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:47] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:47] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:49] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:50] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:51] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:52] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:52] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:53] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:54] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:54] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:55] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:56] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:57] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:11:58] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:00] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:02] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:04] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:05] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:08] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:11] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:14] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:16] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:19] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:21] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:22] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:24] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:27] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:30] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:33] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.
# [16:12:36] WARNING: src/c_api/c_api.cc:935: `ntree_limit` is deprecated, use `iteration_range` instead.

# %%
simulation_xgboost <- function(data, nrun = 10, k_fold = 10, steps = 10){
  # Create empty vector to store loss
  loss <- rep(0, steps)
  # Create empty array to store chosen parameters
  best_params_list <- list()
  # Create empty list to store evaluation dataframes
  eval_list <- list()
  
  # Set the parameters grid for XGBoost
  eta_values <- seq(0.01, 0.3, length.out = steps)
  max_depth_values <- round(seq(3, 9, length.out = steps))
  
  # For loss-calculation factored variables need to be converted to numeric
  if (is.factor(data$income)) {
    print("Target is factor")
    data$income <- as.numeric(as.factor(data$income))
  } else {
    data$income <- as.numeric(data$income)
  }
  
  # Set initial seed
  s <- 1234
  for (i in 1:nrun){
    # Vary seed with each run
    s <- s + 1
    set.seed(s)
    
    # Randomly split the data set into k subsets (or k folds)
    datalist <- split(data, sample(1:k_fold, nrow(data), replace = TRUE))
    
    # Perform k-fold cross-validation
    for (j in 1:k_fold) {
      # Split data in k folds
      data_val <- datalist[[j]]               # j-th of the k folds, validation set
      data_train <- do.call(rbind, datalist[-j])   # Rest of the data without j-th of the k folds, training set
      
      train_X <- convert_to_numeric_matrix(data_train[, !colnames(data_train) %in% 'income'])
      train_y <- data_train$income
      
      val_X <- convert_to_numeric_matrix(data_val[, !colnames(data_val) %in% 'income'])
      val_y <- data_val$income
      
      train_dmatrix <- xgb.DMatrix(data = train_X, label = train_y)
      val_dmatrix <- xgb.DMatrix(data = val_X, label = val_y)
      
      for (eta in eta_values) {
        for (max_depth in max_depth_values) {
          params <- list(
            objective = if (is.factor(data$income)) "multi:softprob" else "reg:squarederror",
            eta = eta,
            max_depth = max_depth
          )
          if (is.factor(data$income)) {
            params$num_class <- length(unique(data$income))
          }
          
          model <- xgb.train(params = params, data = train_dmatrix, nrounds = 100, verbose = 0)
          predictions <- predict(model, val_dmatrix)
          
          if (is.factor(data$income)) {
            epsilon <- 1e-15
            predicted_probs <- pmax(pmin(predictions, 1 - epsilon), epsilon)
            n <- length(predicted_probs)
            loss[j] <- -sum(as.numeric(val_y) * log(predicted_probs) + (1 - as.numeric(val_y)) * log(1 - predicted_probs)) / n
          } else {
            loss[j] <- mean((predictions - val_y)^2)
          }
        }
      }
    }
    
    mean_loss <- mean(loss)
    
    best_eta <- eta_values[which.min(loss)]
    best_max_depth <- max_depth_values[which.min(loss)]
    
    best_params_list[[i]] <- list(eta = best_eta, max_depth = best_max_depth)
    
    final_params <- list(
      objective = if (is.factor(data$income)) "multi:softprob" else "reg:squarederror",
      eta = best_eta,
      max_depth = best_max_depth,
      num_class = if (is.factor(data$income)) length(unique(data$income)) else NULL
    )
    
    final_model <- xgb.train(params = final_params, data = xgb.DMatrix(data = convert_to_numeric_matrix(data[, !colnames(data) %in% 'income']), label = data$income), nrounds = 100, verbose = 0)
    final_predictions <- predict(final_model, xgb.DMatrix(data = convert_to_numeric_matrix(data[, !colnames(data) %in% 'income'])))
    
    # Evaluation metrics
    if (is.factor(data$income)) {
      eval <- as.data.frame(evaluation_metrics_factor(final_predictions, data$income))
    } else {
      eval <- as.data.frame(evaluation_metrics_cont(final_predictions, data$income))
    }
    
    eval_list[[i]] <- eval
    print(c("Run", i, "completed"))
  }
  
  # Average over all runs
  sum_df <- Reduce(function(x, y) Map(`+`, x, y), eval_list)
  eval_avg <- lapply(sum_df, function(col) col / length(eval_list))
  
  # Convert the list back to a dataframe
  # Store row names
  rownames <- row.names(eval_list[[1]])
  
  # Convert the list back to a dataframe
  eval_avg <- as.data.frame(eval_avg)
  
  # Set back the row names
  row.names(eval_avg) <- rownames
  
  # Returns
  results <- list(eval_avg = eval_avg, best_params_list = best_params_list)
  return(results)
}

# %%
cps_res <- simulation_xgboost(cpspop)

# %%
adult_res <- simulation(adult)

# %% [markdown]
# ### Save results

# %%
# Bind results
boosting_pred_results <- list(cps_res = cps_res, adult_res = adult_res)
# File pth for output
file <- "/user/emma.foessing01/u11969/results/boosting_pred_results.RData" 
dir.create(dirname(output_file), recursive = TRUE, showWarnings = FALSE) # create dir if not there
# Save the results to an RData file 
save(results, file = output_file)
